# %% [markdown]
# #  Consignes
#
# ## Description
#
# Ouvrir le fichier ks-projects-201801.csv, il recense environ 100 000 projets KickStarter. Intégrer les données directement avec L'API Python dans une base de données Mongo.
#
# Il conviendra de bien spécifier manuellement l'ID du document. Pensez aussi à bien formatter le type des données pour profiter des méthodes implémentées par Mongo. L'ensemble de données n'est pas forcément nécessaire, c'est à vous de créer votre modèle de données.
#
# ## Questions
#
# - 1) Récupérer les 5 projets ayant reçu le plus de promesse de dons.
# - 2) Compter le nombre de projets ayant atteint leur but.
# - 3) Compter le nombre de projets pour chaque catégorie.
# - 4) Compter le nombre de projets français ayant été instanciés avant 2016.
# - 5) Récupérer les projets américains ayant demandé plus de 200 000 dollars.
# - 6) Compter le nombre de projet ayant "Sport" dans leur nom

# %%
import pandas as pd
import pymongo

# %%
client = pymongo.MongoClient('mongodb://localhost:27017/')
database = client['exercices']
collection = database['kickstarter']

# %%
df_ks = pd.read_csv("./data/ks-projects-201801-sample.csv")
df_ks.head()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (6,8,10,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#            ID                                               name  \
# 0   872782264    Scott Cooper's Solo CD "A Leg Trick" (Canceled)
# 1  1326492673                                    Ohceola jewelry
# 2  1688410639  Sluff Off & Harald: Two latest EGGs are Classi...
# 3   156812982  SketchPlanner: Create and Plan- all in one bea...
# 4  1835968190    Proven sales with custom motorcycle accessories
#
#          category main_category currency    deadline   goal  \
# 0            Rock         Music      USD  2011-09-16   2000
# 1         Fashion       Fashion      USD  2012-08-22  18000
# 2  Tabletop Games         Games      USD  2016-07-19   2000
# 3       Art Books    Publishing      USD  2017-09-27  13000
# 4       Sculpture           Art      CAD  2016-02-24   5000
#
#               launched pledged       state backers country usd pledged  \
# 0  2011-08-17 06:31:31    1145    canceled      24      US        1145
# 1  2012-07-23 20:46:48    1851      failed      28      US        1851
# 2  2016-07-01 21:55:54    7534  successful     254      US        3796
# 3  2017-08-28 15:47:02   16298  successful     367      US        2670
# 4  2016-01-25 17:37:10       1      failed       1      CA    0.708148
#
#    usd_pledged_real
# 0       1145.000000
# 1       1851.000000
# 2       7534.000000
# 3      16298.000000
# 4          0.738225

# %% [markdown]
# Ce warning intervient lorsque pandas n'arrive pas à inférer le type de données. Il est sympa il précise les colones 6,8,10,12.

# %%
df_ks.columns[[6,8,10,12]]
# Out:
# Index(['goal', 'pledged', 'backers', 'usd pledged'], dtype='object')

# %% [markdown]
# ## Question 0

# %% [markdown]
# ### Netoyer les données

# %%
df_ks['launched']=pd.to_datetime(df_ks['launched'],errors='coerce')
df_ks=df_ks.dropna(subset=['launched'])

# %%
df_ks=df_ks.rename(columns={'ID':'_id'})
df_ks.dtypes
# Out:
# _id                          int64
# name                        object
# category                    object
# main_category               object
# currency                    object
# deadline                    object
# goal                        object
# launched            datetime64[ns]
# pledged                     object
# state                       object
# backers                     object
# country                     object
# usd pledged                 object
# usd_pledged_real           float64
# dtype: object

# %%
collection.insert_many(df_ks.to_dict('records'))
collection.find_one()
# Out:
# {'_id': 872782264,
#  'name': 'Scott Cooper\'s Solo CD "A Leg Trick" (Canceled)',
#  'category': 'Rock',
#  'main_category': 'Music',
#  'currency': 'USD',
#  'deadline': '2011-09-16',
#  'goal': 2000.0,
#  'launched': datetime.datetime(2011, 8, 17, 6, 31, 31),
#  'pledged': 1145.0,
#  'state': 'canceled',
#  'backers': 24,
#  'country': 'US',
#  'usd pledged': 1145.0,
#  'usd_pledged_real': 1145.0}

# %% [markdown]
# ### Importer les données

# %% [markdown]
# ## Question 1

# %%
high_goal=collection.find().sort([('goal',-1)]).limit(5)
list(high_goal)
# Out:
# [{'_id': 1693637411,
#   'name': "GTA5 Devin Westin's house in real life (Canceled)",
#   'category': 'Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': '2015-03-21',
#   'goal': '999999.0',
#   'launched': datetime.datetime(2015, 1, 21, 0, 17, 43),
#   'pledged': '0.0',
#   'state': 'canceled',
#   'backers': '0',
#   'country': 'IE',
#   'usd pledged': '0.0',
#   'usd_pledged_real': 0.0},
#  {'_id': 554888187,
#   'name': "'Laborer App' (Canceled)",
#   'category': 'Interactive Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-04-12',
#   'goal': '999999.0',
#   'launched': datetime.datetime(2015, 3, 13, 10, 59, 49),
#   'pledged': '11.0',
#   'state': 'canceled',
#   'backers': '10',
#   'country': 'US',
#   'usd pledged': '11.0',
#   'usd_pledged_real': 11.0},
#  {'_id': 944950980,
#   'name': 'Clouday: The Cheapest Cloud Hosting in the World',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'GBP',
#   'deadline': '2014-09-20',
#   'goal': '99999.0',
#   'launched': datetime.datetime(2014, 7, 22, 17, 59, 47),
#   'pledged': '11.0',
#   'state': 'failed',
#   'backers': '2',
#   'country': 'GB',
#   'usd pledged': '18.80467248',
#   'usd_pledged_real': 17.939267425552046},
#  {'_id': 99201913,
#   'name': 'Babyltop Soccer',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'AUD',
#   'deadline': '2017-09-30',
#   'goal': '99999.0',
#   'launched': datetime.datetime(2017, 8, 3, 4, 27, 1),
#   'pledged': '100.0',
#   'state': 'failed',
#   'backers': '2',
#   'country': 'AU',
#   'usd pledged': '0.0',
#   'usd_pledged_real': 77.73631840796021},
#  {'_id': 329740535,
#   'name': 'Clean Grip - Protect your grip, Travel in Style.',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'GBP',
#   'deadline': '2014-03-20',
#   'goal': '99999.0',
#   'launched': datetime.datetime(2014, 2, 18, 9, 52, 19),
#   'pledged': '86.0',
#   'state': 'failed',
#   'backers': '3',
#   'country': 'GB',
#   'usd pledged': '144.44507884',
#   'usd_pledged_real': 141.8065494838901}]

# %% [markdown]
# ## Question 2

# %%
collection.find({'state':'successful'}).count()
# Out:
# <ipython-input-27-a9bce3fd7108>:1: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   collection.find({'state':'successful'}).count()
# 53040

# %% [markdown]
# ## Question 3

# %%
np=collection.aggregate([
    {'$group':{'_id':'$category','number_project':{'$sum':1}}}
])
list(np)
# Out:
# [{'_id': 'Food', 'number_project': 4612},
#  {'_id': 'Community Gardens', 'number_project': 115},
#  {'_id': 'Metal', 'number_project': 274},
#  {'_id': 'Wearables', 'number_project': 508},
#  {'_id': 'Art', 'number_project': 3358},
#  {'_id': 'Indie Rock', 'number_project': 2192},
#  {'_id': 'Kids', 'number_project': 109},
#  {'_id': 'Taxidermy', 'number_project': 7},
#  {'_id': 'Performances', 'number_project': 414},
#  {'_id': 'Publishing', 'number_project': 2332},
#  {'_id': 'Apparel', 'number_project': 2827},
#  {'_id': 'Classical Music', 'number_project': 1064},
#  {'_id': 'Graphic Design', 'number_project': 765},
#  {'_id': 'Cookbooks', 'number_project': 217},
#  {'_id': 'Bacon', 'number_project': 78},
#  {'_id': 'Fashion', 'number_project': 3379},
#  {'_id': 'Footwear', 'number_project': 379},
#  {'_id': 'Knitting', 'number_project': 78},
#  {'_id': 'Music Videos', 'number_project': 299},
#  {'_id': 'Art Books', 'number_project': 1065},
#  {'_id': 'Faith', 'number_project': 439},
#  {'_id': 'Conceptual Art', 'number_project': 393},
#  {'_id': 'Textiles', 'number_project': 105},
#  {'_id': 'Journalism', 'number_project': 672},
#  {'_id': 'Puzzles', 'number_project': 95},
#  {'_id': 'Places', 'number_project': 283},
#  {'_id': 'Tabletop Games', 'number_project': 5581},
#  {'_id': 'Civic Design', 'number_project': 130},
#  {'_id': 'Zines', 'number_project': 144},
#  {'_id': 'Nonfiction', 'number_project': 3390},
#  {'_id': 'Immersive', 'number_project': 131},
#  {'_id': 'Typography', 'number_project': 44},
#  {'_id': 'Musical', 'number_project': 367},
#  {'_id': 'Shorts', 'number_project': 4857},
#  {'_id': 'Drama', 'number_project': 871},
#  {'_id': 'Webseries', 'number_project': 2316},
#  {'_id': 'Country & Folk', 'number_project': 1790},
#  {'_id': 'Restaurants', 'number_project': 1089},
#  {'_id': 'Webcomics', 'number_project': 259},
#  {'_id': 'Photo', 'number_project': 58},
#  {'_id': 'Video', 'number_project': 147},
#  {'_id': 'Anthologies', 'number_project': 300},
#  {'_id': 'Photography', 'number_project': 2239},
#  {'_id': 'Animation', 'number_project': 1017},
#  {'_id': 'Family', 'number_project': 130},
#  {'_id': 'Young Adult', 'number_project': 328},
#  {'_id': 'Movie Theaters', 'number_project': 90},
#  {'_id': 'Sound', 'number_project': 255},
#  {'_id': 'Television', 'number_project': 401},
#  {'_id': 'Nature', 'number_project': 219},
#  {'_id': 'Architecture', 'number_project': 300},
#  {'_id': 'Horror', 'number_project': 525},
#  {'_id': 'R&B', 'number_project': 172},
#  {'_id': 'Literary Journals', 'number_project': 118},
#  {'_id': 'DIY', 'number_project': 480},
#  {'_id': "Farmer's Markets", 'number_project': 175},
#  {'_id': 'Photobooks', 'number_project': 608},
#  {'_id': 'Radio & Podcasts', 'number_project': 349},
#  {'_id': 'Gadgets', 'number_project': 1210},
#  {'_id': 'Comic Books', 'number_project': 1032},
#  {'_id': 'Video Games', 'number_project': 4799},
#  {'_id': 'Hip-Hop', 'number_project': 1555},
#  {'_id': 'Technology', 'number_project': 2690},
#  {'_id': 'Glass', 'number_project': 51},
#  {'_id': 'Film & Video', 'number_project': 4003},
#  {'_id': 'Accessories', 'number_project': 1204},
#  {'_id': 'Pottery', 'number_project': 40},
#  {'_id': 'Residencies', 'number_project': 32},
#  {'_id': 'Space Exploration', 'number_project': 137},
#  {'_id': 'Jazz', 'number_project': 733},
#  {'_id': 'Punk', 'number_project': 127},
#  {'_id': 'Spaces', 'number_project': 331},
#  {'_id': 'Electronic Music', 'number_project': 858},
#  {'_id': 'Hardware', 'number_project': 1431},
#  {'_id': 'Crafts', 'number_project': 1834},
#  {'_id': 'Blues', 'number_project': 113},
#  {'_id': 'Painting', 'number_project': 1288},
#  {'_id': 'Pet Fashion', 'number_project': 51},
#  {'_id': 'Gaming Hardware', 'number_project': 178},
#  {'_id': 'Fiction', 'number_project': 3703},
#  {'_id': 'Candles', 'number_project': 168},
#  {'_id': 'Theater', 'number_project': 2786},
#  {'_id': 'Camera Equipment', 'number_project': 165},
#  {'_id': 'Product Design', 'number_project': 8886},
#  {'_id': 'Action', 'number_project': 282},
#  {'_id': 'Video Art', 'number_project': 65},
#  {'_id': 'Crochet', 'number_project': 61},
#  {'_id': 'Illustration', 'number_project': 1263},
#  {'_id': 'Woodworking', 'number_project': 433},
#  {'_id': 'Printing', 'number_project': 83},
#  {'_id': 'Fantasy', 'number_project': 132},
#  {'_id': 'Food Trucks', 'number_project': 687},
#  {'_id': 'Festivals', 'number_project': 313},
#  {'_id': 'Fine Art', 'number_project': 291},
#  {'_id': 'Mobile Games', 'number_project': 650},
#  {'_id': 'Chiptune', 'number_project': 10},
#  {'_id': 'Romance', 'number_project': 74},
#  {'_id': 'Graphic Novels', 'number_project': 702},
#  {'_id': '3D Printing', 'number_project': 271},
#  {'_id': 'Comics', 'number_project': 1931},
#  {'_id': 'Audio', 'number_project': 164},
#  {'_id': 'Makerspaces', 'number_project': 91},
#  {'_id': 'Music', 'number_project': 6229},
#  {'_id': 'Academic', 'number_project': 367},
#  {'_id': 'Performance Art', 'number_project': 855},
#  {'_id': 'Weaving', 'number_project': 38},
#  {'_id': 'Digital Art', 'number_project': 524},
#  {'_id': 'Public Art', 'number_project': 1248},
#  {'_id': 'Interactive Design', 'number_project': 146},
#  {'_id': 'Periodicals', 'number_project': 517},
#  {'_id': 'Flight', 'number_project': 158},
#  {'_id': 'Live Games', 'number_project': 394},
#  {'_id': 'Robots', 'number_project': 237},
#  {'_id': 'Design', 'number_project': 1641},
#  {'_id': 'Animals', 'number_project': 97},
#  {'_id': 'Calendars', 'number_project': 112},
#  {'_id': 'Web', 'number_project': 2017},
#  {'_id': 'Pop', 'number_project': 1302},
#  {'_id': 'Rock', 'number_project': 2707},
#  {'_id': 'Ready-to-wear', 'number_project': 332},
#  {'_id': 'Installations', 'number_project': 178},
#  {'_id': 'Jewelry', 'number_project': 472},
#  {'_id': 'Ceramics', 'number_project': 128},
#  {'_id': 'Small Batch', 'number_project': 701},
#  {'_id': 'Workshops', 'number_project': 59},
#  {'_id': 'Quilts', 'number_project': 32},
#  {'_id': 'Print', 'number_project': 288},
#  {'_id': 'Couture', 'number_project': 108},
#  {'_id': 'Thrillers', 'number_project': 302},
#  {'_id': 'Sculpture', 'number_project': 737},
#  {'_id': 'Games', 'number_project': 1331},
#  {'_id': 'Software', 'number_project': 1194},
#  {'_id': 'DIY Electronics', 'number_project': 358},
#  {'_id': "Children's Books", 'number_project': 2686},
#  {'_id': 'Drinks', 'number_project': 995},
#  {'_id': 'Documentary', 'number_project': 6498},
#  {'_id': 'Dance', 'number_project': 901},
#  {'_id': 'Fabrication Tools', 'number_project': 96},
#  {'_id': 'Childrenswear', 'number_project': 192},
#  {'_id': 'People', 'number_project': 440},
#  {'_id': 'Comedy', 'number_project': 923},
#  {'_id': 'Farms', 'number_project': 482},
#  {'_id': 'Vegan', 'number_project': 229},
#  {'_id': 'Events', 'number_project': 322},
#  {'_id': 'Mixed Media', 'number_project': 1118},
#  {'_id': 'Apps', 'number_project': 2535},
#  {'_id': 'Playing Cards', 'number_project': 963},
#  {'_id': 'Experimental', 'number_project': 357},
#  {'_id': 'World Music', 'number_project': 850},
#  {'_id': 'Stationery', 'number_project': 90},
#  {'_id': 'Translations', 'number_project': 76},
#  {'_id': 'Plays', 'number_project': 539},
#  {'_id': 'Poetry', 'number_project': 532},
#  {'_id': 'Science Fiction', 'number_project': 274},
#  {'_id': 'Letterpress', 'number_project': 24},
#  {'_id': 'Embroidery', 'number_project': 49},
#  {'_id': 'Narrative Film', 'number_project': 2099},
#  {'_id': 'Latin', 'number_project': 63},
#  {'_id': 'Literary Spaces', 'number_project': 10}]

# %% [markdown]
# ## Question 4

# %%
import datetime
standard=datetime.datetime(2016,0o1,0o1,0o1)
#french=collection.find({"launched":{"$lte": standard}})
nb_projectfr=collection.aggregate([
    {'$match':{'country':'FR','launched':{'$lte':standard}}},
    {'$group':{'_id':'$name','date':{'$max':'$launched'}}}
])
len(list(nb_projectfr))
# Out:
# 330

# %% [markdown]
# ## Question 5

# %%
america = collection.find({"$and":[{"goal":{"$gte": 200000}}, {"country":"US"}]})
list(america)
# Out:
# [{'_id': 655043686,
#   'name': 'Far from Par is a movie about a man and a talking golf ball.',
#   'category': 'Comedy',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2014-12-05',
#   'goal': 200000.0,
#   'launched': datetime.datetime(2014, 10, 6, 21, 20, 6),
#   'pledged': 10.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 10.0,
#   'usd_pledged_real': 10.0},
#  {'_id': 866634482,
#   'name': 'A CALL TO ADVENTURE',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2012-09-14',
#   'goal': 287000.0,
#   'launched': datetime.datetime(2012, 8, 13, 23, 14, 2),
#   'pledged': 1465.0,
#   'state': 'failed',
#   'backers': 11,
#   'country': 'US',
#   'usd pledged': 1465.0,
#   'usd_pledged_real': 1465.0},
#  {'_id': 993194166,
#   'name': 'Storybricks, the storytelling online RPG',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2012-06-01',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2012, 5, 1, 20, 49, 58),
#   'pledged': 23680.54,
#   'state': 'failed',
#   'backers': 409,
#   'country': 'US',
#   'usd pledged': 23680.54,
#   'usd_pledged_real': 23680.54},
#  {'_id': 1147175344,
#   'name': 'Shine On New World',
#   'category': 'Theater',
#   'main_category': 'Theater',
#   'currency': 'USD',
#   'deadline': '2013-11-04',
#   'goal': 300000.0,
#   'launched': datetime.datetime(2013, 9, 30, 18, 18, 40),
#   'pledged': 12314.0,
#   'state': 'failed',
#   'backers': 50,
#   'country': 'US',
#   'usd pledged': 12314.0,
#   'usd_pledged_real': 12314.0},
#  {'_id': 2012810303,
#   'name': 'Nightclub',
#   'category': 'Music',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2017-09-10',
#   'goal': 3000000.0,
#   'launched': datetime.datetime(2017, 8, 11, 18, 8, 7),
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 1.0},
#  {'_id': 593221398,
#   'name': 'Nastaran (Wild Rose)',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-06-30',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2015, 5, 8, 21, 3, 20),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 621936552,
#   'name': 'Hubo - Extension Box for iPhone',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-11-26',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2016, 10, 27, 17, 43, 14),
#   'pledged': 1996.0,
#   'state': 'failed',
#   'backers': 10,
#   'country': 'US',
#   'usd pledged': 438.0,
#   'usd_pledged_real': 1996.0},
#  {'_id': 1323150226,
#   'name': 'Baja ATV Park (Suspended)',
#   'category': 'Live Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2016-05-31',
#   'goal': 300000.0,
#   'launched': datetime.datetime(2016, 4, 1, 22, 4, 54),
#   'pledged': 11.0,
#   'state': 'suspended',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 11.0,
#   'usd_pledged_real': 11.0},
#  {'_id': 61436443,
#   'name': 'Chihuly Installation for Orlando (Pulse Nightclub)',
#   'category': 'Installations',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2016-08-12',
#   'goal': 1000000.0,
#   'launched': datetime.datetime(2016, 7, 13, 17, 31, 26),
#   'pledged': 5.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 4.0,
#   'usd_pledged_real': 5.0},
#  {'_id': 821637012,
#   'name': 'Kurt Vonnegut: Unstuck in Time',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-03-10',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2015, 2, 10, 14, 5, 34),
#   'pledged': 300319.0,
#   'state': 'successful',
#   'backers': 3755,
#   'country': 'US',
#   'usd pledged': 300319.0,
#   'usd_pledged_real': 300319.0},
#  {'_id': 924370408,
#   'name': 'The LAKE HOPPER is a VTOL Flying Water Craft Made in America',
#   'category': 'Flight',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-12-15',
#   'goal': 3000000.0,
#   'launched': datetime.datetime(2016, 11, 15, 21, 6, 46),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 966762561,
#   'name': '"Hill" (11 For 11) (From the writer of Rudy & Hoosiers)',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2012-12-12',
#   'goal': 1000000.0,
#   'launched': datetime.datetime(2012, 11, 12, 23, 27, 51),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 673847752,
#   'name': 'Saints of The Classroom',
#   'category': 'Television',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2016-11-18',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2016, 10, 19, 2, 5, 16),
#   'pledged': 3085.0,
#   'state': 'failed',
#   'backers': 24,
#   'country': 'US',
#   'usd pledged': 1915.0,
#   'usd_pledged_real': 3085.0},
#  {'_id': 1751772364,
#   'name': 'Hemingwrite - A Distraction Free Digital Typewriter',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-01-23',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2014, 12, 10, 18, 58, 8),
#   'pledged': 342471.0,
#   'state': 'successful',
#   'backers': 1096,
#   'country': 'US',
#   'usd pledged': 342471.0,
#   'usd_pledged_real': 342471.0},
#  {'_id': 1529289950,
#   'name': 'Breakfast 24/7',
#   'category': 'Food',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2016-07-02',
#   'goal': 1000000.0,
#   'launched': datetime.datetime(2016, 5, 18, 0, 36, 35),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 314981144,
#   'name': 'FJE REVOLT',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2015-02-10',
#   'goal': 500000.0,
#   'launched': datetime.datetime(2015, 1, 14, 3, 1, 52),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 208383561,
#   'name': 'Austin City Limits 40 Year History Documentary Film',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2014-09-30',
#   'goal': 400000.0,
#   'launched': datetime.datetime(2014, 8, 29, 20, 46, 59),
#   'pledged': 9.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 9.0,
#   'usd_pledged_real': 9.0},
#  {'_id': 912070501,
#   'name': 'Ozark Mountain Ranch',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-04-06',
#   'goal': 466000.0,
#   'launched': datetime.datetime(2015, 2, 10, 19, 11, 52),
#   'pledged': 1076.0,
#   'state': 'failed',
#   'backers': 5,
#   'country': 'US',
#   'usd pledged': 1076.0,
#   'usd_pledged_real': 1076.0},
#  {'_id': 2116069761,
#   'name': 'STEM Lesson Plan - BotBrainï¿½ Educational Products',
#   'category': 'Software',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-10-07',
#   'goal': 279646.0,
#   'launched': datetime.datetime(2014, 9, 4, 18, 26, 25),
#   'pledged': 85.0,
#   'state': 'failed',
#   'backers': 7,
#   'country': 'US',
#   'usd pledged': 85.0,
#   'usd_pledged_real': 85.0},
#  {'_id': 410799527,
#   'name': 'Guitar Godz VR: A 3D Rock Music Game',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2017-04-04',
#   'goal': 500000.0,
#   'launched': datetime.datetime(2017, 3, 28, 19, 0, 52),
#   'pledged': 22612.0,
#   'state': 'failed',
#   'backers': 36,
#   'country': 'US',
#   'usd pledged': 12311.0,
#   'usd_pledged_real': 22612.0},
#  {'_id': 848767036,
#   'name': "The world's first crowd funded millionaire documentary",
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-05-24',
#   'goal': 1000000.0,
#   'launched': datetime.datetime(2015, 4, 24, 2, 58, 26),
#   'pledged': 171.0,
#   'state': 'failed',
#   'backers': 17,
#   'country': 'US',
#   'usd pledged': 171.0,
#   'usd_pledged_real': 171.0},
#  {'_id': 1520402606,
#   'name': 'Creating an online game, "Perdition Online".',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-11-15',
#   'goal': 350000.0,
#   'launched': datetime.datetime(2013, 9, 16, 22, 49, 11),
#   'pledged': 16.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 16.0,
#   'usd_pledged_real': 16.0},
#  {'_id': 376621995,
#   'name': 'The Adventures of Billy Buskirk',
#   'category': 'Family',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2017-10-14',
#   'goal': 750000.0,
#   'launched': datetime.datetime(2017, 8, 15, 19, 49, 31),
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 1.0,
#   'usd_pledged_real': 1.0},
#  {'_id': 1227415659,
#   'name': 'MY TINSEL TOWN (Canceled)',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-09-13',
#   'goal': 577000.0,
#   'launched': datetime.datetime(2014, 7, 15, 0, 55, 45),
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 520101512,
#   'name': 'Moonlight 5 star (Canceled)',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2016-06-18',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2016, 4, 19, 6, 41, 47),
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1681174007,
#   'name': 'TOMB Adventure 2',
#   'category': 'Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2012-07-16',
#   'goal': 200000.0,
#   'launched': datetime.datetime(2012, 6, 8, 16, 54, 47),
#   'pledged': 5740.0,
#   'state': 'failed',
#   'backers': 54,
#   'country': 'US',
#   'usd pledged': 5740.0,
#   'usd_pledged_real': 5740.0},
#  {'_id': 1038309030,
#   'name': 'The EIFLE S Smart-Mirror W/Front-Facing Camera! (Canceled)',
#   'category': 'Software',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-03-25',
#   'goal': 200000.0,
#   'launched': datetime.datetime(2016, 1, 25, 15, 17, 42),
#   'pledged': 4248.0,
#   'state': 'canceled',
#   'backers': 16,
#   'country': 'US',
#   'usd pledged': 4248.0,
#   'usd_pledged_real': 4248.0},
#  {'_id': 1496553278,
#   'name': 'The Brick Cafe',
#   'category': 'Food',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2016-03-01',
#   'goal': 200000.0,
#   'launched': datetime.datetime(2016, 1, 28, 17, 43, 17),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1256627633,
#   'name': 'Dangerous Seas: A Beautiful Under Water War App (Canceled)',
#   'category': 'Mobile Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2016-06-26',
#   'goal': 400000.0,
#   'launched': datetime.datetime(2016, 5, 27, 17, 52, 3),
#   'pledged': 146.0,
#   'state': 'canceled',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 146.0,
#   'usd_pledged_real': 146.0},
#  {'_id': 2033979252,
#   'name': 'ViewCoze.com | Cozy viewing from home (Canceled)',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-02-01',
#   'goal': 370000.0,
#   'launched': datetime.datetime(2015, 12, 10, 23, 55, 54),
#   'pledged': 80.0,
#   'state': 'canceled',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 80.0,
#   'usd_pledged_real': 80.0},
#  {'_id': 1751639331,
#   'name': 'Meet kubo: an electric scooter to carry all your stuff!',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2013-12-20',
#   'goal': 300000.0,
#   'launched': datetime.datetime(2013, 11, 20, 6, 0, 7),
#   'pledged': 56667.0,
#   'state': 'failed',
#   'backers': 166,
#   'country': 'US',
#   'usd pledged': 56667.0,
#   'usd_pledged_real': 56667.0},
#  {'_id': 1178067412,
#   'name': 'ONEIDNET Social Professional Commercial Corporate Platform',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-03-24',
#   'goal': 545539.0,
#   'launched': datetime.datetime(2017, 2, 22, 19, 24, 24),
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 1.0},
#  {'_id': 175370281,
#   'name': 'Civilian Cam',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-10-06',
#   'goal': 200000.0,
#   'launched': datetime.datetime(2015, 8, 7, 22, 42, 57),
#   'pledged': 10.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 10.0,
#   'usd_pledged_real': 10.0},
#  {'_id': 499583381,
#   'name': 'The Scariest Movie Ever Created',
#   'category': 'Horror',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-08-22',
#   'goal': 100000000.0,
#   'launched': datetime.datetime(2015, 7, 23, 21, 44, 2),
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 1.0,
#   'usd_pledged_real': 1.0},
#  {'_id': 290390319,
#   'name': 'The SEED Project',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2013-01-17',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2012, 12, 18, 23, 1, 12),
#   'pledged': 35.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 35.0,
#   'usd_pledged_real': 35.0},
#  {'_id': 1560972255,
#   'name': 'NewsRadio Season 6 (Canceled)',
#   'category': 'Television',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-12-16',
#   'goal': 3000000.0,
#   'launched': datetime.datetime(2015, 10, 17, 0, 40, 32),
#   'pledged': 101.0,
#   'state': 'canceled',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 101.0,
#   'usd_pledged_real': 101.0},
#  {'_id': 1876072493,
#   'name': 'Get Me Me Kids (Books, Music, Film & Games)',
#   'category': "Children's Books",
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2015-10-10',
#   'goal': 500000.0,
#   'launched': datetime.datetime(2015, 9, 10, 22, 58, 39),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1517530930,
#   'name': "Daniel's Dream",
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-06-21',
#   'goal': 2000000.0,
#   'launched': datetime.datetime(2013, 5, 22, 22, 2, 9),
#   'pledged': 60.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 60.0,
#   'usd_pledged_real': 60.0},
#  {'_id': 658943325,
#   'name': 'iFly Hand Held Camera Crane- pan AND tilt - iPhone GoPro etc',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2012-12-16',
#   'goal': 444000.0,
#   'launched': datetime.datetime(2012, 11, 5, 19, 5, 56),
#   'pledged': 3439.0,
#   'state': 'failed',
#   'backers': 11,
#   'country': 'US',
#   'usd pledged': 3439.0,
#   'usd_pledged_real': 3439.0},
#  {'_id': 420095150,
#   'name': 'GolferVox',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-07-23',
#   'goal': 1200000.0,
#   'launched': datetime.datetime(2015, 6, 23, 21, 12, 43),
#   'pledged': 70.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 70.0,
#   'usd_pledged_real': 70.0},
#  {'_id': 668413973,
#   'name': 'Power Rangers | fan film reboot movie',
#   'category': 'Action',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2016-02-06',
#   'goal': 400000.0,
#   'launched': datetime.datetime(2015, 12, 8, 21, 34, 39),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1481048815,
#   'name': '"Another Network" Film Project',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2014-05-15',
#   'goal': 225000.0,
#   'launched': datetime.datetime(2014, 3, 31, 22, 46, 31),
#   'pledged': 55.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 55.0,
#   'usd_pledged_real': 55.0},
#  {'_id': 1916952451,
#   'name': 'SELF-SUSTAINING ORGANIC FARM',
#   'category': 'Farms',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2014-12-09',
#   'goal': 450000.0,
#   'launched': datetime.datetime(2014, 10, 10, 17, 48, 13),
#   'pledged': 11.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 11.0,
#   'usd_pledged_real': 11.0},
#  {'_id': 1554575493,
#   'name': 'Fuel-X-Tender',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-07-31',
#   'goal': 500000.0,
#   'launched': datetime.datetime(2014, 7, 1, 4, 18, 43),
#   'pledged': 272.0,
#   'state': 'failed',
#   'backers': 6,
#   'country': 'US',
#   'usd pledged': 272.0,
#   'usd_pledged_real': 272.0},
#  {'_id': 1601085300,
#   'name': 'Salad Barr ( the new fast food restaurant )',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2016-03-26',
#   'goal': 270000.0,
#   'launched': datetime.datetime(2016, 2, 26, 0, 4, 18),
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 1.0,
#   'usd_pledged_real': 1.0},
#  {'_id': 1636574067,
#   'name': 'We want your money (Suspended)',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-08-03',
#   'goal': 300000.0,
#   'launched': datetime.datetime(2016, 6, 4, 16, 51, 18),
#   'pledged': 123.0,
#   'state': 'suspended',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 123.0,
#   'usd_pledged_real': 123.0},
#  {'_id': 773987836,
#   'name': "Dutch's Kegs",
#   'category': 'Small Batch',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2015-12-22',
#   'goal': 1000000.0,
#   'launched': datetime.datetime(2015, 11, 17, 23, 36, 6),
#   'pledged': 260.0,
#   'state': 'failed',
#   'backers': 17,
#   'country': 'US',
#   'usd pledged': 260.0,
#   'usd_pledged_real': 260.0},
#  {'_id': 1831435950,
#   'name': 'Pro Tailgater Party Plate',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-05-31',
#   'goal': 365000.0,
#   'launched': datetime.datetime(2017, 4, 25, 21, 25, 17),
#   'pledged': 200.0,
#   'state': 'failed',
#   'backers': 4,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 200.0},
#  {'_id': 178255149,
#   'name': 'Gabriel Device - Free energy for everyone',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-12-14',
#   'goal': 500000.0,
#   'launched': datetime.datetime(2017, 11, 14, 1, 35, 25),
#   'pledged': 81.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 40.0,
#   'usd_pledged_real': 81.0},
#  {'_id': 1098261281,
#   'name': 'Pallet Wars, Part 1...Two More Weeks and Billions Are Ours!!',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2017-11-30',
#   'goal': 875000.0,
#   'launched': datetime.datetime(2017, 10, 31, 6, 35, 30),
#   'pledged': 5.0,
#   'state': 'canceled',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 5.0},
#  {'_id': 849179016,
#   'name': 'Fast Easy Lightweight Modular Cabinets PhastPhurniture',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2017-04-25',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2017, 3, 11, 3, 10, 44),
#   'pledged': 710.0,
#   'state': 'failed',
#   'backers': 5,
#   'country': 'US',
#   'usd pledged': 200.0,
#   'usd_pledged_real': 710.0},
#  {'_id': 1855118124,
#   'name': 'Sonic Chao World fan game (Canceled)',
#   'category': 'Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-02-14',
#   'goal': 1000000.0,
#   'launched': datetime.datetime(2015, 1, 15, 23, 33, 34),
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 326838990,
#   'name': 'StreamStick: The Future of Streaming TV and Media (Canceled)',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-08-17',
#   'goal': 200000.0,
#   'launched': datetime.datetime(2015, 7, 8, 18, 42, 7),
#   'pledged': 4433.0,
#   'state': 'canceled',
#   'backers': 26,
#   'country': 'US',
#   'usd pledged': 4433.0,
#   'usd_pledged_real': 4433.0},
#  {'_id': 607916149,
#   'name': 'The Darkest Dawn',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-06-28',
#   'goal': 500000.0,
#   'launched': datetime.datetime(2013, 5, 29, 4, 48, 42),
#   'pledged': 5.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 5.0,
#   'usd_pledged_real': 5.0},
#  {'_id': 696960534,
#   'name': 'Adventure Combat Ops - A real life, apocalyptic video game!',
#   'category': 'Live Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2014-07-24',
#   'goal': 400000.0,
#   'launched': datetime.datetime(2014, 6, 24, 1, 26, 37),
#   'pledged': 320.0,
#   'state': 'failed',
#   'backers': 5,
#   'country': 'US',
#   'usd pledged': 320.0,
#   'usd_pledged_real': 320.0},
#  {'_id': 966045318,
#   'name': 'Haboob Wind - The Movie',
#   'category': 'Drama',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2017-12-31',
#   'goal': 200000.0,
#   'launched': datetime.datetime(2017, 11, 16, 19, 49, 52),
#   'pledged': 125.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 100.0,
#   'usd_pledged_real': 125.0},
#  {'_id': 2053440575,
#   'name': "World's First Smart Football",
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-05-03',
#   'goal': 500000.0,
#   'launched': datetime.datetime(2015, 4, 3, 1, 17, 58),
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 1.0,
#   'usd_pledged_real': 1.0},
#  {'_id': 397353040,
#   'name': 'The Maryanne Godboldo Story (Canceled)',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-07-20',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2013, 6, 20, 1, 17, 50),
#   'pledged': 2350.0,
#   'state': 'canceled',
#   'backers': 45,
#   'country': 'US',
#   'usd pledged': 2350.0,
#   'usd_pledged_real': 2350.0},
#  {'_id': 534082236,
#   'name': 'M.A.C.S. (Canceled)',
#   'category': 'Space Exploration',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-12-08',
#   'goal': 400000.0,
#   'launched': datetime.datetime(2014, 10, 24, 20, 53, 50),
#   'pledged': 8.0,
#   'state': 'canceled',
#   'backers': 4,
#   'country': 'US',
#   'usd pledged': 8.0,
#   'usd_pledged_real': 8.0},
#  {'_id': 1733658269,
#   'name': 'Keeping my best friends dream alive after losing to cancer',
#   'category': 'DIY',
#   'main_category': 'Crafts',
#   'currency': 'USD',
#   'deadline': '2014-08-13',
#   'goal': 200000.0,
#   'launched': datetime.datetime(2014, 7, 14, 16, 23, 40),
#   'pledged': 5.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 5.0,
#   'usd_pledged_real': 5.0},
#  {'_id': 1957695328,
#   'name': 'Planetary Annihilation - A Next Generation RTS',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2012-09-14',
#   'goal': 900000.0,
#   'launched': datetime.datetime(2012, 8, 15, 21, 20, 10),
#   'pledged': 2229344.36,
#   'state': 'successful',
#   'backers': 44162,
#   'country': 'US',
#   'usd pledged': 2229344.36,
#   'usd_pledged_real': 2229344.36},
#  {'_id': 1618218442,
#   'name': "Pontruff's Pop Shop, Pizza, and Punk Rock",
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2014-09-26',
#   'goal': 500000.0,
#   'launched': datetime.datetime(2014, 7, 28, 9, 5, 22),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1402370273,
#   'name': 'The Good Fight of Faith',
#   'category': 'Family',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-11-19',
#   'goal': 1000000.0,
#   'launched': datetime.datetime(2015, 10, 20, 0, 56, 49),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 410651072,
#   'name': 'Film Adaptation of "The Traveler"',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2016-10-31',
#   'goal': 1000000.0,
#   'launched': datetime.datetime(2016, 10, 1, 19, 42, 33),
#   'pledged': 25.0,
#   'state': 'canceled',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 25.0},
#  {'_id': 670536219,
#   'name': 'Boulder Creek Brewery and Cafe Rebuild (Canceled)',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2015-05-23',
#   'goal': 200000.0,
#   'launched': datetime.datetime(2015, 4, 15, 8, 33, 33),
#   'pledged': 12397.0,
#   'state': 'canceled',
#   'backers': 86,
#   'country': 'US',
#   'usd pledged': 12397.0,
#   'usd_pledged_real': 12397.0},
#  {'_id': 489938719,
#   'name': 'Uncommon Wealth',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-11-24',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2013, 9, 25, 18, 39, 9),
#   'pledged': 2110.0,
#   'state': 'failed',
#   'backers': 18,
#   'country': 'US',
#   'usd pledged': 2110.0,
#   'usd_pledged_real': 2110.0},
#  {'_id': 1730464042,
#   'name': 'Design the Starship Enterprise Science Research Mock Up',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2013-12-02',
#   'goal': 313550.0,
#   'launched': datetime.datetime(2013, 10, 18, 9, 18, 13),
#   'pledged': 31.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 31.0,
#   'usd_pledged_real': 31.0},
#  {'_id': 1517172285,
#   'name': 'Backyard Soccer Buddy / Football Mate (Overseas)',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-09-15',
#   'goal': 2000000.0,
#   'launched': datetime.datetime(2016, 7, 20, 18, 37, 9),
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 469586156,
#   'name': 'Frickin! Fleasï¿½ Mobile Game',
#   'category': 'Mobile Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2017-10-28',
#   'goal': 200000.0,
#   'launched': datetime.datetime(2017, 9, 14, 21, 41, 45),
#   'pledged': 353.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 250.0,
#   'usd_pledged_real': 353.0},
#  {'_id': 1523176093,
#   'name': '"anonymous (street meat)" (Canceled)',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2012-06-17',
#   'goal': 1000000.0,
#   'launched': datetime.datetime(2012, 5, 18, 8, 18, 34),
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1555404895,
#   'name': 'Better Days',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2011-02-04',
#   'goal': 200000.0,
#   'launched': datetime.datetime(2010, 12, 6, 20, 15, 52),
#   'pledged': 50.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 50.0,
#   'usd_pledged_real': 50.0},
#  {'_id': 851609835,
#   'name': 'Akaneiro: Demon Hunters',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-02-03',
#   'goal': 200000.0,
#   'launched': datetime.datetime(2013, 1, 4, 0, 27, 43),
#   'pledged': 204680.93,
#   'state': 'successful',
#   'backers': 2681,
#   'country': 'US',
#   'usd pledged': 204680.93,
#   'usd_pledged_real': 204680.93},
#  {'_id': 934554143,
#   'name': 'Hello Space Boy!',
#   'category': 'Animation',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2016-07-31',
#   'goal': 2000000.0,
#   'launched': datetime.datetime(2016, 6, 3, 23, 59, 11),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1452500654,
#   'name': 'Interactive Breastfeeding Documentary',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2011-09-20',
#   'goal': 210000.0,
#   'launched': datetime.datetime(2011, 8, 2, 15, 54, 48),
#   'pledged': 12058.3,
#   'state': 'failed',
#   'backers': 117,
#   'country': 'US',
#   'usd pledged': 12058.3,
#   'usd_pledged_real': 12058.3},
#  {'_id': 1783703627,
#   'name': 'Aquaponics system for supplying fresh organic food.',
#   'category': 'Farms',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2016-06-05',
#   'goal': 8000000.0,
#   'launched': datetime.datetime(2016, 4, 6, 20, 30, 5),
#   'pledged': 21.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 21.0,
#   'usd_pledged_real': 21.0},
#  {'_id': 1028997654,
#   'name': 'After Reset RPG',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-12-11',
#   'goal': 900000.0,
#   'launched': datetime.datetime(2013, 11, 11, 10, 41, 59),
#   'pledged': 47939.0,
#   'state': 'failed',
#   'backers': 1362,
#   'country': 'US',
#   'usd pledged': 47939.0,
#   'usd_pledged_real': 47939.0},
#  {'_id': 731780695,
#   'name': 'SLAYING GIANTS #GOLIATH',
#   'category': 'Movie Theaters',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2016-08-20',
#   'goal': 350000.0,
#   'launched': datetime.datetime(2016, 7, 21, 3, 42, 14),
#   'pledged': 2508.0,
#   'state': 'failed',
#   'backers': 26,
#   'country': 'US',
#   'usd pledged': 175.0,
#   'usd_pledged_real': 2508.0},
#  {'_id': 776004598,
#   'name': 'Fan News',
#   'category': 'Journalism',
#   'main_category': 'Journalism',
#   'currency': 'USD',
#   'deadline': '2015-03-19',
#   'goal': 275000.0,
#   'launched': datetime.datetime(2015, 2, 17, 19, 40, 55),
#   'pledged': 10.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 10.0,
#   'usd_pledged_real': 10.0},
#  {'_id': 580110957,
#   'name': '*FLASHLIFE* Most Complete Emergency Survival Product Ever.',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-11-05',
#   'goal': 350000.0,
#   'launched': datetime.datetime(2016, 9, 21, 20, 21, 50),
#   'pledged': 1865.0,
#   'state': 'failed',
#   'backers': 14,
#   'country': 'US',
#   'usd pledged': 1.0,
#   'usd_pledged_real': 1865.0},
#  {'_id': 644614031,
#   'name': "Iota: Never lose sight of what's important.",
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-08-14',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2014, 7, 15, 8, 19, 5),
#   'pledged': 282155.0,
#   'state': 'successful',
#   'backers': 1657,
#   'country': 'US',
#   'usd pledged': 282155.0,
#   'usd_pledged_real': 282155.0},
#  {'_id': 281465042,
#   'name': 'RHN - THE REAL HIP-HOP NETWORK TV CHANNEL  DOCUMENTARY',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2014-06-15',
#   'goal': 2000000.0,
#   'launched': datetime.datetime(2014, 5, 1, 20, 1, 10),
#   'pledged': 225.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 225.0,
#   'usd_pledged_real': 225.0},
#  {'_id': 1675510469,
#   'name': 'LAN Center',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-10-26',
#   'goal': 200000.0,
#   'launched': datetime.datetime(2014, 9, 26, 8, 19, 38),
#   'pledged': 2.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 2.0,
#   'usd_pledged_real': 2.0},
#  {'_id': 588787421,
#   'name': 'jfg76tukv u',
#   'category': 'Art',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2015-12-31',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2015, 11, 19, 16, 47, 3),
#   'pledged': 2.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 2.0,
#   'usd_pledged_real': 2.0},
#  {'_id': 742934297,
#   'name': 'Shaft in Asia Featured Film',
#   'category': 'Action',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-10-13',
#   'goal': 1000000.0,
#   'launched': datetime.datetime(2015, 8, 14, 22, 56, 40),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 715019941,
#   'name': 'P.U.R.E. Gamers',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-10-04',
#   'goal': 500000.0,
#   'launched': datetime.datetime(2015, 8, 6, 22, 22),
#   'pledged': 25.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 25.0,
#   'usd_pledged_real': 25.0},
#  {'_id': 818541249,
#   'name': 'The Hawaiian Girl Art Studio (Canceled)',
#   'category': 'Digital Art',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2016-03-24',
#   'goal': 1100000.0,
#   'launched': datetime.datetime(2016, 1, 26, 5, 48, 5),
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1312071514,
#   'name': 'The Rock Bar - Mobile Bar/Event Platform',
#   'category': 'Events',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2015-05-24',
#   'goal': 200000.0,
#   'launched': datetime.datetime(2015, 4, 9, 1, 28, 16),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 206228383,
#   'name': 'The Wager',
#   'category': 'Action',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-04-12',
#   'goal': 200000.0,
#   'launched': datetime.datetime(2015, 2, 11, 20, 2),
#   'pledged': 10.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 10.0,
#   'usd_pledged_real': 10.0},
#  {'_id': 466162671,
#   'name': 'xFaire: A TV Device. Watch Any Content, Anytime & Anywhere',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-07-21',
#   'goal': 200000.0,
#   'launched': datetime.datetime(2016, 6, 6, 20, 36, 49),
#   'pledged': 3523.0,
#   'state': 'canceled',
#   'backers': 29,
#   'country': 'US',
#   'usd pledged': 3227.0,
#   'usd_pledged_real': 3523.0},
#  {'_id': 1051776765,
#   'name': 'Independent Broadcasting Company',
#   'category': 'Television',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2017-05-31',
#   'goal': 700000.0,
#   'launched': datetime.datetime(2017, 4, 1, 2, 34, 51),
#   'pledged': 56.0,
#   'state': 'canceled',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 56.0,
#   'usd_pledged_real': 56.0},
#  {'_id': 595664945,
#   'name': 'Forbidden Woods (Canceled)',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2012-08-18',
#   'goal': 2300000.0,
#   'launched': datetime.datetime(2012, 7, 19, 21, 12, 51),
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1348230166,
#   'name': "Max and Rex's Adventure",
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2012-05-12',
#   'goal': 200000.0,
#   'launched': datetime.datetime(2012, 3, 28, 4, 6, 56),
#   'pledged': 4286.0,
#   'state': 'failed',
#   'backers': 21,
#   'country': 'US',
#   'usd pledged': 4286.0,
#   'usd_pledged_real': 4286.0},
#  {'_id': 788197692,
#   'name': 'The Guilt Free Life',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2014-08-27',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2014, 6, 28, 22, 5, 3),
#   'pledged': 20.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 20.0,
#   'usd_pledged_real': 20.0},
#  {'_id': 1254965074,
#   'name': 'Mayacama Chocolate-Bean-to-Bar Craft Chocolate, Napa,Ca',
#   'category': 'Small Batch',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2015-04-19',
#   'goal': 780000.0,
#   'launched': datetime.datetime(2015, 2, 18, 17, 23, 50),
#   'pledged': 267.0,
#   'state': 'failed',
#   'backers': 6,
#   'country': 'US',
#   'usd pledged': 267.0,
#   'usd_pledged_real': 267.0},
#  {'_id': 178418310,
#   'name': 'Puzzle Camp',
#   'category': 'Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2014-06-18',
#   'goal': 750000.0,
#   'launched': datetime.datetime(2014, 5, 19, 3, 56, 46),
#   'pledged': 35.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 35.0,
#   'usd_pledged_real': 35.0},
#  {'_id': 1473597203,
#   'name': 'Vehroot Shelf | Use Your Phone or Tablet as Your Car Stereo',
#   'category': 'Sound',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2018-01-11',
#   'goal': 500000.0,
#   'launched': datetime.datetime(2017, 12, 12, 18, 46, 26),
#   'pledged': 5651.0,
#   'state': 'live',
#   'backers': 14,
#   'country': 'US',
#   'usd pledged': 1248.0,
#   'usd_pledged_real': 5651.0},
#  {'_id': 715203303,
#   'name': "THE YING YANG MURDER MYSTERY'S (Canceled)",
#   'category': 'Webseries',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2014-12-31',
#   'goal': 900000.0,
#   'launched': datetime.datetime(2014, 12, 1, 23, 50, 57),
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 374403417,
#   'name': 'Montgomery Al Concert 5FDP and VOLBEAT',
#   'category': 'Rock',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2014-07-24',
#   'goal': 1040000.0,
#   'launched': datetime.datetime(2014, 6, 24, 2, 58, 50),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1935538858,
#   'name': 'Wall Scaler',
#   'category': 'Flight',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-04-17',
#   'goal': 1000000.0,
#   'launched': datetime.datetime(2017, 3, 3, 21, 30, 39),
#   'pledged': 1.0,
#   'state': 'suspended',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 1.0},
#  {'_id': 1926637288,
#   'name': 'Historic B&B with an in-house French Bakery in Memphis, TN',
#   'category': 'Food',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2016-07-23',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2016, 6, 23, 1, 13, 20),
#   'pledged': 10100.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 10100.0,
#   'usd_pledged_real': 10100.0},
#  {'_id': 781443672,
#   'name': 'Eternal Fate',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2012-09-01',
#   'goal': 200000.0,
#   'launched': datetime.datetime(2012, 8, 2, 7, 36, 8),
#   'pledged': 12914.0,
#   'state': 'failed',
#   'backers': 234,
#   'country': 'US',
#   'usd pledged': 12914.0,
#   'usd_pledged_real': 12914.0},
#  {'_id': 1715597415,
#   'name': 'Angelz Landing the Movie',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2014-02-17',
#   'goal': 1200000.0,
#   'launched': datetime.datetime(2014, 1, 13, 19, 8, 9),
#   'pledged': 356.0,
#   'state': 'failed',
#   'backers': 5,
#   'country': 'US',
#   'usd pledged': 356.0,
#   'usd_pledged_real': 356.0},
#  {'_id': 779336498,
#   'name': 'Morrison Land',
#   'category': 'Movie Theaters',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2014-07-27',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2014, 5, 28, 19, 42, 35),
#   'pledged': 10.0,
#   'state': 'failed',
#   'backers': 6,
#   'country': 'US',
#   'usd pledged': 10.0,
#   'usd_pledged_real': 10.0},
#  {'_id': 1934580784,
#   'name': 'Triple Espresso Goes to The Big Apple',
#   'category': 'Theater',
#   'main_category': 'Theater',
#   'currency': 'USD',
#   'deadline': '2013-03-16',
#   'goal': 300000.0,
#   'launched': datetime.datetime(2013, 2, 9, 21, 1, 57),
#   'pledged': 27581.0,
#   'state': 'failed',
#   'backers': 116,
#   'country': 'US',
#   'usd pledged': 27581.0,
#   'usd_pledged_real': 27581.0},
#  {'_id': 107644423,
#   'name': 'Meetupgolf - Everything Golf, Everything Social',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-09-21',
#   'goal': 200000.0,
#   'launched': datetime.datetime(2016, 8, 22, 18, 44, 37),
#   'pledged': 360.0,
#   'state': 'canceled',
#   'backers': 8,
#   'country': 'US',
#   'usd pledged': 25.0,
#   'usd_pledged_real': 360.0},
#  {'_id': 1081925218,
#   'name': 'GunDetect - alerts you when it sees a gun',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-08-20',
#   'goal': 200000.0,
#   'launched': datetime.datetime(2015, 7, 15, 1, 3, 4),
#   'pledged': 43718.0,
#   'state': 'failed',
#   'backers': 10,
#   'country': 'US',
#   'usd pledged': 43718.0,
#   'usd_pledged_real': 43718.0},
#  {'_id': 1596314651,
#   'name': 'Take And Seek the Movie',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-09-16',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2013, 8, 16, 4, 59, 36),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1834526569,
#   'name': 'Unsung Story: Tale of the Guardians',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2014-02-15',
#   'goal': 600000.0,
#   'launched': datetime.datetime(2014, 1, 14, 19, 3, 30),
#   'pledged': 660126.51,
#   'state': 'successful',
#   'backers': 15824,
#   'country': 'US',
#   'usd pledged': 660126.51,
#   'usd_pledged_real': 660126.51},
#  {'_id': 2007557271,
#   'name': 'Harishwar Center for Arts, Spirituality & Sustainability',
#   'category': 'Architecture',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-02-03',
#   'goal': 1800000.0,
#   'launched': datetime.datetime(2016, 1, 4, 20, 26, 57),
#   'pledged': 614.0,
#   'state': 'failed',
#   'backers': 14,
#   'country': 'US',
#   'usd pledged': 614.0,
#   'usd_pledged_real': 614.0},
#  {'_id': 695668947,
#   'name': "The Cancer Patient's Film Project",
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-08-17',
#   'goal': 1500000.0,
#   'launched': datetime.datetime(2013, 7, 12, 2, 38, 19),
#   'pledged': 275.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 275.0,
#   'usd_pledged_real': 275.0},
#  {'_id': 832080779,
#   'name': "Small Change: Kids' Financial Life Skills",
#   'category': 'Software',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-08-11',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2014, 7, 17, 15, 54, 12),
#   'pledged': 3536.0,
#   'state': 'failed',
#   'backers': 39,
#   'country': 'US',
#   'usd pledged': 3536.0,
#   'usd_pledged_real': 3536.0},
#  {'_id': 1656648684,
#   'name': 'Save the Williamsburg',
#   'category': 'Public Art',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2015-10-27',
#   'goal': 40000000.0,
#   'launched': datetime.datetime(2015, 9, 27, 15, 8, 5),
#   'pledged': 21700.0,
#   'state': 'failed',
#   'backers': 15,
#   'country': 'US',
#   'usd pledged': 21700.0,
#   'usd_pledged_real': 21700.0},
#  {'_id': 256448010,
#   'name': 'Nephilim, Nazis and the New World Order',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-07-12',
#   'goal': 500000.0,
#   'launched': datetime.datetime(2015, 5, 13, 3, 45, 32),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 978588144,
#   'name': 'War At Home',
#   'category': 'Drama',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-11-28',
#   'goal': 340000.0,
#   'launched': datetime.datetime(2015, 10, 29, 16, 0, 52),
#   'pledged': 19328.0,
#   'state': 'failed',
#   'backers': 273,
#   'country': 'US',
#   'usd pledged': 19328.0,
#   'usd_pledged_real': 19328.0},
#  {'_id': 208391519,
#   'name': 'North East',
#   'category': 'Drama',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2017-07-23',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2017, 5, 24, 0, 17, 26),
#   'pledged': 2.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 2.0},
#  {'_id': 1789241689,
#   'name': 'The Great Pyramid, Project USA',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-08-01',
#   'goal': 300000.0,
#   'launched': datetime.datetime(2014, 6, 2, 15, 53, 58),
#   'pledged': 35.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 35.0,
#   'usd_pledged_real': 35.0},
#  {'_id': 2126842880,
#   'name': 'Time travel app',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-10-09',
#   'goal': 375000.0,
#   'launched': datetime.datetime(2017, 9, 12, 21, 6, 34),
#   'pledged': 135.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 10.0,
#   'usd_pledged_real': 135.0},
#  {'_id': 1046230768,
#   'name': 'Honolulu Haze (Canceled)',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-07-07',
#   'goal': 500000.0,
#   'launched': datetime.datetime(2013, 5, 8, 18, 0, 16),
#   'pledged': 70.0,
#   'state': 'canceled',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 70.0,
#   'usd_pledged_real': 70.0},
#  {'_id': 2135350794,
#   'name': 'Motor Sports Mailboxes',
#   'category': 'Crafts',
#   'main_category': 'Crafts',
#   'currency': 'USD',
#   'deadline': '2015-01-18',
#   'goal': 600000.0,
#   'launched': datetime.datetime(2014, 11, 19, 20, 20, 55),
#   'pledged': 200.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 200.0,
#   'usd_pledged_real': 200.0},
#  {'_id': 381953552,
#   'name': 'Patented MoveNetic Lock - New Post 9-11 Locking Method',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-10-08',
#   'goal': 350000.0,
#   'launched': datetime.datetime(2014, 9, 3, 1, 33, 36),
#   'pledged': 60.0,
#   'state': 'canceled',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 60.0,
#   'usd_pledged_real': 60.0},
#  {'_id': 2108775311,
#   'name': 'Where Is the Love? (A Dedication to Love) (Canceled)',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2012-07-12',
#   'goal': 200000.0,
#   'launched': datetime.datetime(2012, 6, 12, 0, 35, 18),
#   'pledged': 5.0,
#   'state': 'canceled',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 5.0,
#   'usd_pledged_real': 5.0},
#  {'_id': 1393231622,
#   'name': 'Love Over A Million Years',
#   'category': 'Movie Theaters',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2016-02-10',
#   'goal': 200000.0,
#   'launched': datetime.datetime(2015, 12, 12, 4, 53, 7),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 749406436,
#   'name': 'Hoverboard: The Next Evolution in Personal Electric Mobility',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-10-22',
#   'goal': 500000.0,
#   'launched': datetime.datetime(2015, 9, 17, 16, 39, 3),
#   'pledged': 257275.0,
#   'state': 'failed',
#   'backers': 239,
#   'country': 'US',
#   'usd pledged': 257275.0,
#   'usd_pledged_real': 257275.0},
#  {'_id': 1812682282,
#   'name': 'Make A South African Feature Film! (Canceled)',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2011-12-31',
#   'goal': 2500000.0,
#   'launched': datetime.datetime(2011, 12, 5, 17, 22, 45),
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 892520897,
#   'name': 'Feature-Length Movie: Secret of the Missing Grave',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-07-02',
#   'goal': 10000000.0,
#   'launched': datetime.datetime(2013, 5, 3, 23, 15, 16),
#   'pledged': 11975.0,
#   'state': 'failed',
#   'backers': 24,
#   'country': 'US',
#   'usd pledged': 11975.0,
#   'usd_pledged_real': 11975.0},
#  {'_id': 396599619,
# ...
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 244546725,
#   'name': 'All Race Matters! (Canceled)',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2016-03-20',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2016, 1, 20, 2, 33, 33),
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1838463372,
#   'name': 'Petcube Bites + Petcube Play: Treat & Care for Pets Remotely',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-09-02',
#   'goal': 200000.0,
#   'launched': datetime.datetime(2016, 7, 19, 15, 2, 20),
#   'pledged': 319193.0,
#   'state': 'successful',
#   'backers': 2229,
#   'country': 'US',
#   'usd pledged': 18208.0,
#   'usd_pledged_real': 319193.0},
#  {'_id': 324618003,
#   'name': 'Top-down Action RPG, Indie Developed',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2016-08-26',
#   'goal': 200000.0,
#   'launched': datetime.datetime(2016, 6, 27, 22, 46, 44),
#   'pledged': 560.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 500.0,
#   'usd_pledged_real': 560.0},
#  {'_id': 129439104,
#   'name': 'Pet Bottle Bowl',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-01-13',
#   'goal': 200000.0,
#   'launched': datetime.datetime(2015, 12, 14, 23, 17, 59),
#   'pledged': 425.0,
#   'state': 'failed',
#   'backers': 8,
#   'country': 'US',
#   'usd pledged': 425.0,
#   'usd_pledged_real': 425.0},
#  {'_id': 1173268530,
#   'name': 'Recording Studio',
#   'category': 'Music',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2018-01-27',
#   'goal': 300000.0,
#   'launched': datetime.datetime(2017, 11, 28, 16, 32, 43),
#   'pledged': 0.0,
#   'state': 'live',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1695316076,
#   'name': 'Candy store & Deli in Clearwater Beach',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2016-03-19',
#   'goal': 500000.0,
#   'launched': datetime.datetime(2016, 2, 18, 23, 58, 35),
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 1.0,
#   'usd_pledged_real': 1.0},
#  {'_id': 109087278,
#   'name': '"FRIGHT PLAN"',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2012-05-21',
#   'goal': 345000.0,
#   'launched': datetime.datetime(2012, 3, 22, 21, 57, 10),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1528855147,
#   'name': 'Rebuild Enzo Ferrari',
#   'category': 'Crafts',
#   'main_category': 'Crafts',
#   'currency': 'USD',
#   'deadline': '2014-11-18',
#   'goal': 2500000.0,
#   'launched': datetime.datetime(2014, 11, 10, 18, 20, 55),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1567939188,
#   'name': 'Electric Vehicle Self Charging system - Drive and Charge',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-01-17',
#   'goal': 300000.0,
#   'launched': datetime.datetime(2014, 12, 3, 10, 25, 7),
#   'pledged': 124.0,
#   'state': 'failed',
#   'backers': 4,
#   'country': 'US',
#   'usd pledged': 124.0,
#   'usd_pledged_real': 124.0},
#  {'_id': 1559938694,
#   'name': 'Sweet Mara film project',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2012-08-07',
#   'goal': 1000000.0,
#   'launched': datetime.datetime(2012, 6, 8, 8, 58, 13),
#   'pledged': 12512.0,
#   'state': 'failed',
#   'backers': 52,
#   'country': 'US',
#   'usd pledged': 12512.0,
#   'usd_pledged_real': 12512.0},
#  {'_id': 192462803,
#   'name': 'Calypso Music Festival',
#   'category': 'Electronic Music',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2015-09-20',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2015, 8, 21, 18, 40, 41),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 303459168,
#   'name': 'Nomasoak-The first truly portable hot tub',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-01-13',
#   'goal': 350000.0,
#   'launched': datetime.datetime(2014, 11, 29, 2, 14, 28),
#   'pledged': 8593.0,
#   'state': 'failed',
#   'backers': 39,
#   'country': 'US',
#   'usd pledged': 8593.0,
#   'usd_pledged_real': 8593.0},
#  {'_id': 1045781653,
#   'name': "Salvators' Winery & Restaurant",
#   'category': 'Food',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2012-03-08',
#   'goal': 3500000.0,
#   'launched': datetime.datetime(2012, 1, 8, 21, 28, 40),
#   'pledged': 125.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 125.0,
#   'usd_pledged_real': 125.0},
#  {'_id': 588609229,
#   'name': 'Mariner Farms: local, closed loop, organic food production.',
#   'category': 'Farms',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2014-09-12',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2014, 8, 12, 0, 17, 11),
#   'pledged': 11.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 11.0,
#   'usd_pledged_real': 11.0},
#  {'_id': 734151954,
#   'name': 'GetActive',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-02-01',
#   'goal': 210000.0,
#   'launched': datetime.datetime(2015, 12, 23, 18, 28, 15),
#   'pledged': 1225.0,
#   'state': 'failed',
#   'backers': 4,
#   'country': 'US',
#   'usd pledged': 1225.0,
#   'usd_pledged_real': 1225.0},
#  {'_id': 2145330072,
#   'name': 'Walk of Fame',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-10-18',
#   'goal': 200000.0,
#   'launched': datetime.datetime(2013, 9, 18, 13, 40, 51),
#   'pledged': 4625.29,
#   'state': 'failed',
#   'backers': 15,
#   'country': 'US',
#   'usd pledged': 4625.29,
#   'usd_pledged_real': 4625.29},
#  {'_id': 15481028,
#   'name': 'Somewhere in Time (Canceled)',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2016-02-17',
#   'goal': 300000.0,
#   'launched': datetime.datetime(2015, 12, 19, 2, 26, 53),
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 495150995,
#   'name': 'Larceny Lock: Make Your Door Kick-in Proof',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-12-02',
#   'goal': 500000.0,
#   'launched': datetime.datetime(2015, 11, 2, 19, 0, 30),
#   'pledged': 156.0,
#   'state': 'failed',
#   'backers': 9,
#   'country': 'US',
#   'usd pledged': 156.0,
#   'usd_pledged_real': 156.0},
#  {'_id': 1013385092,
#   'name': 'Helpeddle',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-06-14',
#   'goal': 210000.0,
#   'launched': datetime.datetime(2015, 5, 5, 19, 57, 43),
#   'pledged': 46.0,
#   'state': 'failed',
#   'backers': 6,
#   'country': 'US',
#   'usd pledged': 46.0,
#   'usd_pledged_real': 46.0},
#  {'_id': 1867847796,
#   'name': 'Ceramic Pie Studios',
#   'category': 'Ceramics',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2017-03-11',
#   'goal': 325000.0,
#   'launched': datetime.datetime(2017, 1, 10, 18, 50, 54),
#   'pledged': 190.0,
#   'state': 'failed',
#   'backers': 6,
#   'country': 'US',
#   'usd pledged': 50.0,
#   'usd_pledged_real': 190.0},
#  {'_id': 904321689,
#   'name': 'Endless Dreams Pillow / Adjustable pillow',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-09-24',
#   'goal': 650000.0,
#   'launched': datetime.datetime(2016, 8, 10, 3, 59, 40),
#   'pledged': 21.0,
#   'state': 'canceled',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 20.0,
#   'usd_pledged_real': 21.0},
#  {'_id': 49416977,
#   'name': '"let go of my eggo - Morning Show"',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2016-11-16',
#   'goal': 200000.0,
#   'launched': datetime.datetime(2016, 10, 17, 22, 44, 40),
#   'pledged': 1000.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 1000.0},
#  {'_id': 1494825882,
#   'name': 'Salt Bill Home Beer Kit',
#   'category': 'Drinks',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2017-08-16',
#   'goal': 425000.0,
#   'launched': datetime.datetime(2017, 7, 17, 23, 46, 14),
#   'pledged': 470.0,
#   'state': 'canceled',
#   'backers': 9,
#   'country': 'US',
#   'usd pledged': 420.0,
#   'usd_pledged_real': 470.0},
#  {'_id': 806983206,
#   'name': 'Kingdom of Oberon',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2014-08-23',
#   'goal': 400000.0,
#   'launched': datetime.datetime(2014, 7, 24, 20, 1, 28),
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 1.0,
#   'usd_pledged_real': 1.0},
#  {'_id': 557660427,
#   'name': 'Shark Tooth Edger',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-10-13',
#   'goal': 475000.0,
#   'launched': datetime.datetime(2016, 9, 13, 0, 23, 42),
#   'pledged': 101.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 101.0},
#  {'_id': 1935410492,
#   'name': 'Bazadee Sports (Canceled)',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-05-06',
#   'goal': 2000000.0,
#   'launched': datetime.datetime(2015, 4, 6, 1, 48, 58),
#   'pledged': 10.0,
#   'state': 'canceled',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 10.0,
#   'usd_pledged_real': 10.0},
#  {'_id': 1763488905,
#   'name': 'SANTA MARIA: THE FIRST VOYAGE',
#   'category': 'Science Fiction',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2014-08-10',
#   'goal': 700000.0,
#   'launched': datetime.datetime(2014, 7, 11, 0, 15, 11),
#   'pledged': 10.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 10.0,
#   'usd_pledged_real': 10.0},
#  {'_id': 1400530801,
#   'name': 'Help us fund a new hobby shop for everyone',
#   'category': 'Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2014-09-21',
#   'goal': 276855.0,
#   'launched': datetime.datetime(2014, 7, 23, 3, 36, 14),
#   'pledged': 5.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 5.0,
#   'usd_pledged_real': 5.0},
#  {'_id': 669788948,
#   'name': 'Earth Sheltered Homes Nightly Rental Project',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-07-24',
#   'goal': 300000.0,
#   'launched': datetime.datetime(2014, 6, 14, 2, 40, 56),
#   'pledged': 3.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 3.0,
#   'usd_pledged_real': 3.0},
#  {'_id': 175515570,
#   'name': 'Trail Of Fears Haunted House',
#   'category': 'Theater',
#   'main_category': 'Theater',
#   'currency': 'USD',
#   'deadline': '2015-08-23',
#   'goal': 500000.0,
#   'launched': datetime.datetime(2015, 8, 3, 21, 9, 18),
#   'pledged': 2.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 2.0,
#   'usd_pledged_real': 2.0},
#  {'_id': 2117696164,
#   'name': 'Miss Wisenheimer and the Aliens',
#   'category': 'Science Fiction',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2016-02-09',
#   'goal': 822996.0,
#   'launched': datetime.datetime(2016, 1, 15, 20, 57, 4),
#   'pledged': 11890.0,
#   'state': 'failed',
#   'backers': 9,
#   'country': 'US',
#   'usd pledged': 11890.0,
#   'usd_pledged_real': 11890.0},
#  {'_id': 1103389637,
#   'name': 'The First Iditarod: The Amazing Dogs & Their Mushers',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2017-04-16',
#   'goal': 235000.0,
#   'launched': datetime.datetime(2017, 3, 2, 23, 56, 29),
#   'pledged': 4645.0,
#   'state': 'failed',
#   'backers': 40,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 4645.0},
#  {'_id': 108469603,
#   'name': "sonoro Cubo: World's First All-In-One SmartHome Audio System",
#   'category': 'Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-07-03',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2016, 5, 4, 12, 48, 19),
#   'pledged': 2150.0,
#   'state': 'canceled',
#   'backers': 8,
#   'country': 'US',
#   'usd pledged': 2150.0,
#   'usd_pledged_real': 2150.0},
#  {'_id': 1231855507,
#   'name': '5 Degrees of Separation (Canceled)',
#   'category': 'Nonfiction',
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2012-08-16',
#   'goal': 1000000.0,
#   'launched': datetime.datetime(2012, 7, 17, 19, 37, 22),
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1553197094,
#   'name': 'Beyond the Pillowed Bed',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2011-12-08',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2011, 10, 29, 18, 18, 59),
#   'pledged': 120.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 120.0,
#   'usd_pledged_real': 120.0},
#  {'_id': 1561401031,
#   'name': 'Camp Oak Hallows - A Wizarding World Experience',
#   'category': 'Immersive',
#   'main_category': 'Theater',
#   'currency': 'USD',
#   'deadline': '2017-01-15',
#   'goal': 1000000.0,
#   'launched': datetime.datetime(2016, 11, 16, 19, 27, 33),
#   'pledged': 75.0,
#   'state': 'canceled',
#   'backers': 6,
#   'country': 'US',
#   'usd pledged': 50.0,
#   'usd_pledged_real': 75.0},
#  {'_id': 1607902753,
#   'name': 'Conscious Conscience',
#   'category': 'Drama',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-11-13',
#   'goal': 1000000.0,
#   'launched': datetime.datetime(2015, 10, 14, 20, 57, 9),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 954984778,
#   'name': 'Theory of the Evolution of Mind',
#   'category': 'Academic',
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2015-08-01',
#   'goal': 200000.0,
#   'launched': datetime.datetime(2015, 7, 7, 21, 22, 40),
#   'pledged': 9010.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 9010.0,
#   'usd_pledged_real': 9010.0},
#  {'_id': 1658211759,
#   'name': 'TeenEdTech',
#   'category': 'Software',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-05-18',
#   'goal': 200000.0,
#   'launched': datetime.datetime(2016, 4, 28, 21, 31, 37),
#   'pledged': 2.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 2.0,
#   'usd_pledged_real': 2.0},
#  {'_id': 1487762306,
#   'name': 'Fund the Freedom to Bear Arms',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2014-10-21',
#   'goal': 200000.0,
#   'launched': datetime.datetime(2014, 8, 22, 17, 56, 32),
#   'pledged': 50.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 50.0,
#   'usd_pledged_real': 50.0},
#  {'_id': 1525174324,
#   'name': 'King of the Dead - A Horror / Comedy Movie',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2012-11-25',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2012, 10, 11, 22, 10, 28),
#   'pledged': 55.0,
#   'state': 'failed',
#   'backers': 4,
#   'country': 'US',
#   'usd pledged': 55.0,
#   'usd_pledged_real': 55.0},
#  {'_id': 1186961197,
#   'name': 'The Brandon Lee Movie Project',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-09-07',
#   'goal': 200000.0,
#   'launched': datetime.datetime(2013, 8, 8, 18, 1, 19),
#   'pledged': 2338.0,
#   'state': 'failed',
#   'backers': 45,
#   'country': 'US',
#   'usd pledged': 2338.0,
#   'usd_pledged_real': 2338.0},
#  ...]

# %% [markdown]
# ## Question 6

# %%
sport=collection.find({'name':{'$regex':'.*Sport.*'}})
list(sport)
# Out:
# [{'_id': 802281658,
#   'name': 'Sportswear range',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'currency': 'AUD',
#   'deadline': '2014-08-23',
#   'goal': 25000.0,
#   'launched': datetime.datetime(2014, 7, 24, 5, 14, 52),
#   'pledged': 20.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'AU',
#   'usd pledged': 18.7569048,
#   'usd_pledged_real': 18.675880100849763},
#  {'_id': 1838460041,
#   'name': 'Mount Systems for Recreation Sports & Film (GoPro) Lighting',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-06-16',
#   'goal': 30000.0,
#   'launched': datetime.datetime(2015, 5, 12, 18, 34, 28),
#   'pledged': 12442.0,
#   'state': 'failed',
#   'backers': 11,
#   'country': 'US',
#   'usd pledged': 12442.0,
#   'usd_pledged_real': 12442.0},
#  {'_id': 767518055,
#   'name': 'E-GoBox: Revolutionary Sports Capsule Dispenser',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2017-08-09',
#   'goal': 60000.0,
#   'launched': datetime.datetime(2017, 7, 10, 5, 51, 37),
#   'pledged': 300.0,
#   'state': 'failed',
#   'backers': 6,
#   'country': 'US',
#   'usd pledged': 225.0,
#   'usd_pledged_real': 300.0},
#  {'_id': 2109408750,
#   'name': 'Biz Sports Weekly',
#   'category': 'Journalism',
#   'main_category': 'Journalism',
#   'currency': 'GBP',
#   'deadline': '2016-08-19',
#   'goal': 5000.0,
#   'launched': datetime.datetime(2016, 7, 20, 16, 15, 57),
#   'pledged': 2.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'GB',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 2.617595476795016},
#  {'_id': 22743603,
#   'name': 'Hugodrawings Sports Wear',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'currency': 'GBP',
#   'deadline': '2016-07-18',
#   'goal': 3000.0,
#   'launched': datetime.datetime(2016, 6, 18, 12, 4, 39),
#   'pledged': 455.0,
#   'state': 'failed',
#   'backers': 14,
#   'country': 'GB',
#   'usd pledged': 590.3465499,
#   'usd_pledged_real': 595.8226936423754},
#  {'_id': 1747603310,
#   'name': 'SHOE-LOCK Sportswear:  No more laces',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-04-11',
#   'goal': 2000.0,
#   'launched': datetime.datetime(2015, 3, 2, 21, 43, 38),
#   'pledged': 2275.0,
#   'state': 'successful',
#   'backers': 47,
#   'country': 'US',
#   'usd pledged': 2275.0,
#   'usd_pledged_real': 2275.0},
#  {'_id': 1362109613,
#   'name': 'LA LAKERS Inspired Sports + Lifestyle Jewelry for the Fans',
#   'category': 'Jewelry',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2016-11-04',
#   'goal': 5100.0,
#   'launched': datetime.datetime(2016, 10, 4, 19, 14, 36),
#   'pledged': 2228.0,
#   'state': 'failed',
#   'backers': 34,
#   'country': 'US',
#   'usd pledged': 525.0,
#   'usd_pledged_real': 2228.0},
#  {'_id': 1423364226,
#   'name': 'SportsFix - The end of not knowing who to play with',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-02-05',
#   'goal': 10000.0,
#   'launched': datetime.datetime(2015, 1, 6, 22, 42, 26),
#   'pledged': 2.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 2.0,
#   'usd_pledged_real': 2.0},
#  {'_id': 321623835,
#   'name': 'DV8 Sports: Golf Without Obstacles',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2014-07-15',
#   'goal': 50000.0,
#   'launched': datetime.datetime(2014, 6, 10, 8, 35, 40),
#   'pledged': 85442.0,
#   'state': 'successful',
#   'backers': 170,
#   'country': 'US',
#   'usd pledged': 85442.0,
#   'usd_pledged_real': 85442.0},
#  {'_id': 1178595391,
#   'name': 'ICUBALLING: Live youth Sports fundraising (HQ)',
#   'category': 'Webseries',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2014-04-10',
#   'goal': 30000.0,
#   'launched': datetime.datetime(2014, 3, 3, 15, 2, 47),
#   'pledged': 460.0,
#   'state': 'failed',
#   'backers': 6,
#   'country': 'US',
#   'usd pledged': 460.0,
#   'usd_pledged_real': 460.0},
#  {'_id': 1672240130,
#   'name': 'WarriorteX - 100% American Made Performance Sportswear',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-11-07',
#   'goal': 150000.0,
#   'launched': datetime.datetime(2016, 9, 23, 17, 23, 38),
#   'pledged': 737.0,
#   'state': 'failed',
#   'backers': 8,
#   'country': 'US',
#   'usd pledged': 250.0,
#   'usd_pledged_real': 737.0},
#  {'_id': 205654323,
#   'name': 'Sports, Fitness and Faith magazine',
#   'category': 'Periodicals',
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2016-05-13',
#   'goal': 20000.0,
#   'launched': datetime.datetime(2016, 4, 13, 19, 5, 24),
#   'pledged': 127.0,
#   'state': 'failed',
#   'backers': 7,
#   'country': 'US',
#   'usd pledged': 127.0,
#   'usd_pledged_real': 127.0},
#  {'_id': 2147349697,
#   'name': 'RELAJ Sports Water Bottle  - SHAPED FOR SAFETY',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2014-05-04',
#   'goal': 15000.0,
#   'launched': datetime.datetime(2014, 3, 20, 0, 41, 30),
#   'pledged': 4095.0,
#   'state': 'failed',
#   'backers': 77,
#   'country': 'US',
#   'usd pledged': 4095.0,
#   'usd_pledged_real': 4095.0},
#  {'_id': 644756884,
#   'name': 'FanFix Sports - Present. Discuss. Host. Change.',
#   'category': 'Web',
#   'main_category': 'Journalism',
#   'currency': 'USD',
#   'deadline': '2015-09-27',
#   'goal': 25000.0,
#   'launched': datetime.datetime(2015, 8, 28, 16, 8, 13),
#   'pledged': 145.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 145.0,
#   'usd_pledged_real': 145.0},
#  {'_id': 552869945,
#   'name': 'the Indiana Sports Report',
#   'category': 'Web',
#   'main_category': 'Journalism',
#   'currency': 'USD',
#   'deadline': '2014-08-24',
#   'goal': 5000.0,
#   'launched': datetime.datetime(2014, 7, 10, 17, 45, 10),
#   'pledged': 110.0,
#   'state': 'failed',
#   'backers': 4,
#   'country': 'US',
#   'usd pledged': 110.0,
#   'usd_pledged_real': 110.0},
#  {'_id': 1696158836,
#   'name': 'Sports Card Magazine is ready!',
#   'category': 'Journalism',
#   'main_category': 'Journalism',
#   'currency': 'USD',
#   'deadline': '2013-02-21',
#   'goal': 5000.0,
#   'launched': datetime.datetime(2013, 1, 13, 1, 12, 18),
#   'pledged': 590.0,
#   'state': 'failed',
#   'backers': 10,
#   'country': 'US',
#   'usd pledged': 590.0,
#   'usd_pledged_real': 590.0},
#  {'_id': 865678989,
#   'name': 'Avada Gaming E-Sports Organisation',
#   'category': 'Games',
#   'main_category': 'Games',
#   'currency': 'AUD',
#   'deadline': '2014-08-20',
#   'goal': 1000.0,
#   'launched': datetime.datetime(2014, 7, 16, 2, 15, 51),
#   'pledged': 5.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'AU',
#   'usd pledged': 4.699446900000001,
#   'usd_pledged_real': 4.655926995064717},
#  {'_id': 1854354367,
#   'name': 'Learn a Foreign Language While Playing Sports',
#   'category': 'Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-05-06',
#   'goal': 2500.0,
#   'launched': datetime.datetime(2015, 4, 21, 21, 29, 27),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1864518952,
#   'name': 'The Daily Sports Buzz TV and Web Show !',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-07-06',
#   'goal': 4000.0,
#   'launched': datetime.datetime(2013, 6, 6, 8, 47, 27),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 2135350794,
#   'name': 'Motor Sports Mailboxes',
#   'category': 'Crafts',
#   'main_category': 'Crafts',
#   'currency': 'USD',
#   'deadline': '2015-01-18',
#   'goal': 600000.0,
#   'launched': datetime.datetime(2014, 11, 19, 20, 20, 55),
#   'pledged': 200.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 200.0,
#   'usd_pledged_real': 200.0},
#  {'_id': 15871755,
#   'name': 'SKLeague eSports',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'CAD',
#   'deadline': '2016-01-25',
#   'goal': 5500.0,
#   'launched': datetime.datetime(2016, 1, 4, 22, 0, 49),
#   'pledged': 991.0,
#   'state': 'failed',
#   'backers': 11,
#   'country': 'CA',
#   'usd pledged': 715.75550771,
#   'usd_pledged_real': 704.3855284668422},
#  {'_id': 2066287444,
#   'name': 'apr?s | Premium After-Sport Seat Cover',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-03-08',
#   'goal': 7250.0,
#   'launched': datetime.datetime(2015, 2, 5, 0, 46, 43),
#   'pledged': 1760.0,
#   'state': 'failed',
#   'backers': 23,
#   'country': 'US',
#   'usd pledged': 1760.0,
#   'usd_pledged_real': 1760.0},
#  {'_id': 12584764,
#   'name': 'Sports Cards Unlimited (Canceled)',
#   'category': 'Playing Cards',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-11-15',
#   'goal': 400000.0,
#   'launched': datetime.datetime(2015, 10, 16, 21, 19),
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1146143519,
#   'name': 'Dolfin Pack Xtreme Sports Hydration System',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2014-05-23',
#   'goal': 10000.0,
#   'launched': datetime.datetime(2014, 4, 23, 21, 44, 3),
#   'pledged': 11115.0,
#   'state': 'successful',
#   'backers': 198,
#   'country': 'US',
#   'usd pledged': 11115.0,
#   'usd_pledged_real': 11115.0},
#  {'_id': 1870839048,
#   'name': 'Sport and Entertainment Podcast',
#   'category': 'Audio',
#   'main_category': 'Journalism',
#   'currency': 'USD',
#   'deadline': '2015-01-29',
#   'goal': 2000.0,
#   'launched': datetime.datetime(2015, 1, 15, 1, 13, 35),
#   'pledged': 47.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 47.0,
#   'usd_pledged_real': 47.0},
#  {'_id': 1327934829,
#   'name': "The 'ETTA EXPRESS (The Best-Kept Secret In Sports)",
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2012-09-22',
#   'goal': 150000.0,
#   'launched': datetime.datetime(2012, 8, 23, 0, 34, 10),
#   'pledged': 16586.0,
#   'state': 'failed',
#   'backers': 38,
#   'country': 'US',
#   'usd pledged': 16586.0,
#   'usd_pledged_real': 16586.0},
#  {'_id': 447285607,
#   'name': 'FragSource eSports Network',
#   'category': 'Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-08-24',
#   'goal': 3600.0,
#   'launched': datetime.datetime(2015, 7, 10, 13, 44, 57),
#   'pledged': 25.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 25.0,
#   'usd_pledged_real': 25.0},
#  {'_id': 1750363014,
#   'name': 'Ride Skincare - Natural Skincare for Outdoor Sports',
#   'category': 'Design',
#   'main_category': 'Design',
#   'currency': 'GBP',
#   'deadline': '2016-11-18',
#   'goal': 7000.0,
#   'launched': datetime.datetime(2016, 10, 24, 8, 32, 25),
#   'pledged': 748.0,
#   'state': 'failed',
#   'backers': 28,
#   'country': 'GB',
#   'usd pledged': 181.05082868,
#   'usd_pledged_real': 922.1362000098624},
#  {'_id': 410012915,
#   'name': 'FIERCE Sportswear',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'GBP',
#   'deadline': '2017-03-17',
#   'goal': 1000.0,
#   'launched': datetime.datetime(2017, 2, 15, 9, 22, 41),
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'GB',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 1.2360175514492304},
#  {'_id': 946363782,
#   'name': 'Help us Launch AGON - New Sports Medicine Apparel Brand',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2016-05-03',
#   'goal': 80000.0,
#   'launched': datetime.datetime(2016, 3, 4, 3, 32, 26),
#   'pledged': 19.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 19.0,
#   'usd_pledged_real': 19.0},
#  {'_id': 1126822169,
#   'name': 'Frey Sports App - We connect sports people.',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'DKK',
#   'deadline': '2017-01-11',
#   'goal': 25000.0,
#   'launched': datetime.datetime(2016, 12, 12, 11, 30, 28),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'DK',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 759625825,
#   'name': 'Pickup Sports World',
#   'category': 'Software',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-02-02',
#   'goal': 20000.0,
#   'launched': datetime.datetime(2017, 1, 3, 2, 4, 52),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1332899780,
#   'name': 'iLikeitNerdy eSports arcade',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2018-01-18',
#   'goal': 20000.0,
#   'launched': datetime.datetime(2017, 12, 19, 20, 39, 36),
#   'pledged': 1868.22,
#   'state': 'live',
#   'backers': 25,
#   'country': 'US',
#   'usd pledged': 410.0,
#   'usd_pledged_real': 1868.22},
#  {'_id': 1687313162,
#   'name': 'Create the NEW ComedySportz Improv Theatre in Richmond!',
#   'category': 'Theater',
#   'main_category': 'Theater',
#   'currency': 'USD',
#   'deadline': '2011-04-03',
#   'goal': 10000.0,
#   'launched': datetime.datetime(2011, 2, 12, 0, 41, 58),
#   'pledged': 10521.0,
#   'state': 'successful',
#   'backers': 134,
#   'country': 'US',
#   'usd pledged': 10521.0,
#   'usd_pledged_real': 10521.0},
#  {'_id': 844622643,
#   'name': 'Pro League E-Sports',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2016-08-01',
#   'goal': 50000.0,
#   'launched': datetime.datetime(2016, 6, 20, 23, 1, 57),
#   'pledged': 500.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 500.0},
#  {'_id': 632369959,
#   'name': 'SportChat',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'CAD',
#   'deadline': '2017-02-26',
#   'goal': 50000.0,
#   'launched': datetime.datetime(2016, 12, 28, 18, 5, 36),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'CA',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 543613283,
#   'name': 'Vivacity ï¿½ Sportswear for Every Part of Your Day',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2013-05-09',
#   'goal': 20000.0,
#   'launched': datetime.datetime(2013, 4, 9, 18, 26, 4),
#   'pledged': 5115.0,
#   'state': 'failed',
#   'backers': 38,
#   'country': 'US',
#   'usd pledged': 5115.0,
#   'usd_pledged_real': 5115.0},
#  {'_id': 415048408,
#   'name': '500 Level: Unique Officially Licensed Sports Tshirts',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2013-08-28',
#   'goal': 20000.0,
#   'launched': datetime.datetime(2013, 7, 14, 19, 7, 9),
#   'pledged': 21213.0,
#   'state': 'successful',
#   'backers': 376,
#   'country': 'US',
#   'usd pledged': 21213.0,
#   'usd_pledged_real': 21213.0},
#  {'_id': 1388748869,
#   'name': 'Derbyshire Sport Scene',
#   'category': 'Journalism',
#   'main_category': 'Journalism',
#   'currency': 'GBP',
#   'deadline': '2014-10-29',
#   'goal': 1000.0,
#   'launched': datetime.datetime(2014, 9, 30, 0, 39, 12),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'GB',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 33300581,
#   'name': 'Cyber Sports Monthly (Canceled)',
#   'category': 'Periodicals',
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2013-01-22',
#   'goal': 15000.0,
#   'launched': datetime.datetime(2012, 12, 23, 17, 8, 32),
#   'pledged': 162.0,
#   'state': 'canceled',
#   'backers': 5,
#   'country': 'US',
#   'usd pledged': 162.0,
#   'usd_pledged_real': 162.0},
#  {'_id': 72535161,
#   'name': 'Nanaue eSports',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2016-02-11',
#   'goal': 5000.0,
#   'launched': datetime.datetime(2016, 1, 28, 17, 18, 30),
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 1.0,
#   'usd_pledged_real': 1.0},
#  {'_id': 1916832,
#   'name': 'Dog Power: A Look Into the Fastest Dogs & Newest Dog Sports',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-11-15',
#   'goal': 33462.0,
#   'launched': datetime.datetime(2015, 10, 16, 21, 46, 25),
#   'pledged': 34858.0,
#   'state': 'successful',
#   'backers': 389,
#   'country': 'US',
#   'usd pledged': 34858.0,
#   'usd_pledged_real': 34858.0},
#  {'_id': 1523192703,
#   'name': 'Sport Ball Bags',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2017-05-13',
#   'goal': 3000.0,
#   'launched': datetime.datetime(2017, 4, 13, 2, 7, 23),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1018822517,
#   'name': 'Massive LEGO Truman Sports Complex',
#   'category': 'Sculpture',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2014-08-21',
#   'goal': 16137.0,
#   'launched': datetime.datetime(2014, 7, 19, 23, 53, 29),
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 1.0,
#   'usd_pledged_real': 1.0},
#  {'_id': 784739167,
#   'name': 'KYMIRA Sport: An Evolution in Sportswear',
#   'category': 'Wearables',
#   'main_category': 'Technology',
#   'currency': 'GBP',
#   'deadline': '2014-05-16',
#   'goal': 25000.0,
#   'launched': datetime.datetime(2014, 4, 16, 14, 3, 31),
#   'pledged': 13903.0,
#   'state': 'failed',
#   'backers': 58,
#   'country': 'GB',
#   'usd pledged': 23241.74047458,
#   'usd_pledged_real': 23369.528676124522},
#  {'_id': 87488242,
#   'name': 'SnapDrafts: Daily Fantasy Sports',
#   'category': 'Live Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-04-25',
#   'goal': 100000.0,
#   'launched': datetime.datetime(2015, 3, 26, 21, 48, 26),
#   'pledged': 500.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 500.0,
#   'usd_pledged_real': 500.0},
#  {'_id': 1959821013,
#   'name': "Get Real Girl: Sport action figures empowering today's girls",
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-11-19',
#   'goal': 40000.0,
#   'launched': datetime.datetime(2016, 10, 20, 19, 15, 14),
#   'pledged': 44305.33,
#   'state': 'successful',
#   'backers': 243,
#   'country': 'US',
#   'usd pledged': 380.0,
#   'usd_pledged_real': 44305.33},
#  {'_id': 1439161310,
#   'name': 'Rohnert Park LAN Center/eSports facility',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2014-05-06',
#   'goal': 4000.0,
#   'launched': datetime.datetime(2014, 4, 22, 18, 35, 37),
#   'pledged': 1605.0,
#   'state': 'failed',
#   'backers': 19,
#   'country': 'US',
#   'usd pledged': 1605.0,
#   'usd_pledged_real': 1605.0},
#  {'_id': 422509694,
#   'name': '"American Sports Stories" - An Athletic Quest',
#   'category': 'Television',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2017-05-14',
#   'goal': 100000.0,
#   'launched': datetime.datetime(2017, 4, 14, 0, 8, 52),
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 25.0,
#   'usd_pledged_real': 1.0},
#  {'_id': 2073829586,
#   'name': 'FLootball.com- A Fantasy Football, RPG, Sports game Mashup',
#   'category': 'Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-05-01',
#   'goal': 20000.0,
#   'launched': datetime.datetime(2015, 3, 17, 17, 1, 30),
#   'pledged': 110.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 110.0,
#   'usd_pledged_real': 110.0},
#  {'_id': 462355371,
#   'name': 'MySportsFeeds - crowd-sourced sports data for fans',
#   'category': 'Live Games',
#   'main_category': 'Games',
#   'currency': 'CAD',
#   'deadline': '2015-05-01',
#   'goal': 25000.0,
#   'launched': datetime.datetime(2015, 4, 1, 19, 39, 17),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'CA',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1050771565,
#   'name': 'The Pro Lounge / Gaming Restaurant & eSport Event Hosting',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2017-08-01',
#   'goal': 200000.0,
#   'launched': datetime.datetime(2017, 6, 13, 6, 21, 48),
#   'pledged': 75.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 75.0,
#   'usd_pledged_real': 75.0},
#  {'_id': 312464012,
#   'name': 'Loopio & Loopio Sport | Never lose your keys or phone again.',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'GBP',
#   'deadline': '2015-06-17',
#   'goal': 30000.0,
#   'launched': datetime.datetime(2015, 5, 13, 23, 18, 4),
#   'pledged': 7461.0,
#   'state': 'failed',
#   'backers': 216,
#   'country': 'GB',
#   'usd pledged': 11621.51339202,
#   'usd_pledged_real': 11816.97234628908},
#  {'_id': 1222567604,
#   'name': "Altered V3 DS - World's First Dual Sport Electric Skateboard",
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2013-11-23',
#   'goal': 50000.0,
#   'launched': datetime.datetime(2013, 10, 22, 21, 53, 6),
#   'pledged': 22815.0,
#   'state': 'failed',
#   'backers': 52,
#   'country': 'US',
#   'usd pledged': 22815.0,
#   'usd_pledged_real': 22815.0},
#  {'_id': 1628639695,
#   'name': 'Sports Gifts made from baseballs/footballs/sofballs',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2014-09-16',
#   'goal': 700.0,
#   'launched': datetime.datetime(2014, 9, 2, 16, 12, 13),
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1021717834,
#   'name': 'SportKit: Accessorize your Olympus Air A01 digital camera',
#   'category': 'Camera Equipment',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-02-23',
#   'goal': 21700.0,
#   'launched': datetime.datetime(2017, 1, 24, 17, 20, 34),
#   'pledged': 279.0,
#   'state': 'canceled',
#   'backers': 4,
#   'country': 'US',
#   'usd pledged': 130.0,
#   'usd_pledged_real': 279.0},
#  {'_id': 918031988,
#   'name': "Good Sport Book - A Children's Book on Sportsmanship",
#   'category': "Children's Books",
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2012-09-15',
#   'goal': 5000.0,
#   'launched': datetime.datetime(2012, 8, 16, 2, 54, 40),
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 1.0,
#   'usd_pledged_real': 1.0},
#  {'_id': 1901105792,
#   'name': 'Sports Emblems',
#   'category': 'Crafts',
#   'main_category': 'Crafts',
#   'currency': 'USD',
#   'deadline': '2014-12-10',
#   'goal': 10000.0,
#   'launched': datetime.datetime(2014, 11, 10, 22, 51, 40),
#   'pledged': 6.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 6.0,
#   'usd_pledged_real': 6.0},
#  {'_id': 2105052828,
#   'name': 'Elite-Sports-Worldwide- presents all around sports socks!',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2012-07-22',
#   'goal': 10000.0,
#   'launched': datetime.datetime(2012, 6, 22, 17, 52, 6),
#   'pledged': 100.0,
#   'state': 'canceled',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 100.0,
#   'usd_pledged_real': 100.0},
#  {'_id': 114396613,
#   'name': 'The Sport Revolution on your SmartPhone',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2016-11-09',
#   'goal': 4650.0,
#   'launched': datetime.datetime(2016, 9, 30, 20, 48, 23),
#   'pledged': 636.0,
#   'state': 'failed',
#   'backers': 7,
#   'country': 'ES',
#   'usd pledged': 113.40669254,
#   'usd_pledged_real': 693.4979118734258},
#  {'_id': 599433495,
#   'name': 'Water Sports Enthusiast Clothing by Water-Borne',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2012-11-09',
#   'goal': 5000.0,
#   'launched': datetime.datetime(2012, 10, 10, 17, 52, 29),
#   'pledged': 25.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 25.0,
#   'usd_pledged_real': 25.0},
#  {'_id': 415264066,
#   'name': 'Sportfestival Buitenadem',
#   'category': 'Music',
#   'main_category': 'Music',
#   'currency': 'EUR',
#   'deadline': '2015-04-30',
#   'goal': 30000.0,
#   'launched': datetime.datetime(2015, 3, 22, 10, 38, 38),
#   'pledged': 321.0,
#   'state': 'failed',
#   'backers': 6,
#   'country': 'NL',
#   'usd pledged': 347.34320205,
#   'usd_pledged_real': 360.00269160890923},
#  {'_id': 1024116205,
#   'name': '2017 Support - Soccer Sports Open Data',
#   'category': 'Software',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2017-01-08',
#   'goal': 500.0,
#   'launched': datetime.datetime(2016, 12, 9, 16, 48, 37),
#   'pledged': 6.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'IT',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 6.3965884861407245},
#  {'_id': 144139366,
#   'name': 'Ace eSports',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2017-02-18',
#   'goal': 20000.0,
#   'launched': datetime.datetime(2016, 12, 20, 9, 24, 37),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'ES',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1275259290,
#   'name': 'iWhite - Sport Nutrition - Restaurant',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'currency': 'EUR',
#   'deadline': '2015-11-01',
#   'goal': 140000.0,
#   'launched': datetime.datetime(2015, 9, 17, 13, 32, 30),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'DE',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1658515944,
#   'name': 'Super Slam Dunk Touchdown: A Sports Game For Everybody!',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-03-29',
#   'goal': 15000.0,
#   'launched': datetime.datetime(2015, 2, 27, 3, 17),
#   'pledged': 5428.0,
#   'state': 'failed',
#   'backers': 132,
#   'country': 'US',
#   'usd pledged': 5428.0,
#   'usd_pledged_real': 5428.0},
#  {'_id': 312991396,
#   'name': 'eSports Tournaments (Canceled)',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-08-30',
#   'goal': 27000.0,
#   'launched': datetime.datetime(2015, 7, 3, 17, 15, 33),
#   'pledged': 2.0,
#   'state': 'canceled',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 2.0,
#   'usd_pledged_real': 2.0},
#  {'_id': 729181791,
#   'name': 'Poor Sports- iBook created by a 6 year old Creative Wizard',
#   'category': "Children's Books",
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2013-04-05',
#   'goal': 1500.0,
#   'launched': datetime.datetime(2013, 3, 6, 18, 54, 6),
#   'pledged': 410.0,
#   'state': 'failed',
#   'backers': 6,
#   'country': 'US',
#   'usd pledged': 410.0,
#   'usd_pledged_real': 410.0},
#  {'_id': 746676343,
#   'name': 'The 90 Degree Show on NBC Sports',
#   'category': 'Music',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2017-10-30',
#   'goal': 1800.0,
#   'launched': datetime.datetime(2017, 9, 28, 23, 17, 29),
#   'pledged': 173.0,
#   'state': 'failed',
#   'backers': 4,
#   'country': 'US',
#   'usd pledged': 22.0,
#   'usd_pledged_real': 173.0},
#  {'_id': 137733484,
#   'name': "'Cursed' - The Cleveland Sports Story",
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2012-01-07',
#   'goal': 35000.0,
#   'launched': datetime.datetime(2011, 11, 8, 21, 19, 16),
#   'pledged': 425.0,
#   'state': 'failed',
#   'backers': 18,
#   'country': 'US',
#   'usd pledged': 425.0,
#   'usd_pledged_real': 425.0},
#  {'_id': 1771971822,
#   'name': 'Bright Stools:  Any Sport, Any Season, Any Event.',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-01-12',
#   'goal': 200000.0,
#   'launched': datetime.datetime(2014, 11, 13, 5, 51),
#   'pledged': 2893.0,
#   'state': 'failed',
#   'backers': 7,
#   'country': 'US',
#   'usd pledged': 2893.0,
#   'usd_pledged_real': 2893.0},
#  {'_id': 69383759,
#   'name': '"ACTION" A Gallery Showing For Action Sports',
#   'category': 'Shorts',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2010-12-09',
#   'goal': 5000.0,
#   'launched': datetime.datetime(2010, 10, 25, 4, 29, 3),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1573405970,
#   'name': '~FrogSportsBoards~',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-03-04',
#   'goal': 162500.0,
#   'launched': datetime.datetime(2016, 1, 20, 22, 20, 37),
#   'pledged': 1160.0,
#   'state': 'failed',
#   'backers': 9,
#   'country': 'US',
#   'usd pledged': 1160.0,
#   'usd_pledged_real': 1160.0},
#  {'_id': 2083908527,
#   'name': 'Build a Large Scale Version  of the Airsailer Sports Balloon',
#   'category': 'Flight',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-10-11',
#   'goal': 47600.0,
#   'launched': datetime.datetime(2014, 8, 12, 8, 28, 36),
#   'pledged': 17.0,
#   'state': 'canceled',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 17.0,
#   'usd_pledged_real': 17.0},
#  {'_id': 2072875895,
#   'name': 'Odds Hacker - Sports Betting and Fantasy Sports Predictions',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-10-15',
#   'goal': 60000.0,
#   'launched': datetime.datetime(2015, 9, 15, 15, 45, 34),
#   'pledged': 16000.0,
#   'state': 'failed',
#   'backers': 17,
#   'country': 'US',
#   'usd pledged': 16000.0,
#   'usd_pledged_real': 16000.0},
#  {'_id': 1935189722,
#   'name': 'KickFlip Mafia Action Sports Clothing',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2012-07-26',
#   'goal': 5000.0,
#   'launched': datetime.datetime(2012, 6, 11, 22, 5, 27),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 684627152,
#   'name': 'Dream Skating Sports Planner',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-05-01',
#   'goal': 5000.0,
#   'launched': datetime.datetime(2015, 3, 2, 22, 24, 11),
#   'pledged': 400.0,
#   'state': 'failed',
#   'backers': 6,
#   'country': 'US',
#   'usd pledged': 400.0,
#   'usd_pledged_real': 400.0},
#  {'_id': 2006222883,
#   'name': 'Quakecon 2015 Documentary by WinD of XI Geforce eSports',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-05-09',
#   'goal': 1400.0,
#   'launched': datetime.datetime(2015, 4, 2, 2, 49, 24),
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 95745611,
#   'name': 'McSling: Wearable Sports Equipment or Most Anything Carrier',
#   'category': 'Wearables',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-07-03',
#   'goal': 3500.0,
#   'launched': datetime.datetime(2017, 6, 5, 6, 57, 27),
#   'pledged': 360.0,
#   'state': 'failed',
#   'backers': 11,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 360.0},
#  {'_id': 2134440543,
#   'name': 'Sports Year: 365 Games in 365 Days',
#   'category': 'Nonfiction',
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2013-09-13',
#   'goal': 100000.0,
#   'launched': datetime.datetime(2013, 8, 23, 21, 18, 2),
#   'pledged': 19690.0,
#   'state': 'failed',
#   'backers': 110,
#   'country': 'US',
#   'usd pledged': 19690.0,
#   'usd_pledged_real': 19690.0},
#  {'_id': 1961408855,
#   'name': 'Good Game, Well Played-The Story of Irish eSports.',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': '2016-02-03',
#   'goal': 3500.0,
#   'launched': datetime.datetime(2015, 12, 5, 12, 33, 42),
#   'pledged': 863.37,
#   'state': 'failed',
#   'backers': 15,
#   'country': 'IE',
#   'usd pledged': 943.6356440208,
#   'usd_pledged_real': 967.1446174526717},
#  {'_id': 1741756528,
#   'name': 'Spotbook Spot?s for Sport?s',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-06-30',
#   'goal': 10000.0,
#   'launched': datetime.datetime(2015, 5, 16, 0, 35, 18),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'DE',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 595778535,
#   'name': 'Sports bag "Infinity"',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-11-12',
#   'goal': 10000.0,
#   'launched': datetime.datetime(2016, 10, 13, 15, 38, 34),
#   'pledged': 431.0,
#   'state': 'failed',
#   'backers': 7,
#   'country': 'US',
#   'usd pledged': 280.0,
#   'usd_pledged_real': 431.0},
#  {'_id': 374746825,
#   'name': 'Instant, Mobile, Fantasy Sports.',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-09-19',
#   'goal': 30000.0,
#   'launched': datetime.datetime(2013, 8, 20, 1, 23, 8),
#   'pledged': 30637.0,
#   'state': 'successful',
#   'backers': 56,
#   'country': 'US',
#   'usd pledged': 30637.0,
#   'usd_pledged_real': 30637.0},
#  {'_id': 861051774,
#   'name': 'Utility Sports',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-11-19',
#   'goal': 9999.0,
#   'launched': datetime.datetime(2014, 10, 20, 13, 14, 51),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1699914749,
#   'name': 'Patriot Sports Cards',
#   'category': 'Playing Cards',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2016-04-09',
#   'goal': 90000.0,
#   'launched': datetime.datetime(2016, 3, 10, 21, 24, 11),
#   'pledged': 2.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 2.0,
#   'usd_pledged_real': 2.0},
#  {'_id': 1035330015,
#   'name': 'Matano: Fair Trade Sports Apparel for the Everyday Athlete',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2016-07-06',
#   'goal': 20000.0,
#   'launched': datetime.datetime(2016, 5, 31, 15, 1, 49),
#   'pledged': 6717.0,
#   'state': 'failed',
#   'backers': 82,
#   'country': 'US',
#   'usd pledged': 6717.0,
#   'usd_pledged_real': 6717.0},
#  {'_id': 889804160,
#   'name': 'Combat Sports Hall of Fame - Establishing Online Exhibitions',
#   'category': 'Art',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2014-11-13',
#   'goal': 4000.0,
#   'launched': datetime.datetime(2014, 10, 14, 18, 32, 3),
#   'pledged': 925.0,
#   'state': 'failed',
#   'backers': 12,
#   'country': 'US',
#   'usd pledged': 925.0,
#   'usd_pledged_real': 925.0},
#  {'_id': 767196077,
#   'name': 'New Sports Industry',
#   'category': 'Live Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2016-03-11',
#   'goal': 700000.0,
#   'launched': datetime.datetime(2016, 2, 10, 3, 12, 28),
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 1.0,
#   'usd_pledged_real': 1.0},
#  {'_id': 558384208,
#   'name': 'Sports Stadium Iphone App Development',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-06-13',
#   'goal': 500.0,
#   'launched': datetime.datetime(2015, 5, 14, 3, 35, 49),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1336212200,
#   'name': 'KICKSTARTER Shoulder Strap for Laptop, Sport and Travel bags',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2016-07-25',
#   'goal': 1000.0,
#   'launched': datetime.datetime(2016, 7, 10, 8, 6, 39),
#   'pledged': 2777.0,
#   'state': 'successful',
#   'backers': 63,
#   'country': 'DE',
#   'usd pledged': 708.52216439,
#   'usd_pledged_real': 3086.069900538979},
#  {'_id': 496229694,
#   'name': 'IU: Sports and Travel Vest',
#   'category': 'Accessories',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2015-08-12',
#   'goal': 35000.0,
#   'launched': datetime.datetime(2015, 7, 13, 17, 49, 57),
#   'pledged': 761.0,
#   'state': 'failed',
#   'backers': 11,
#   'country': 'US',
#   'usd pledged': 761.0,
#   'usd_pledged_real': 761.0},
#  {'_id': 619119405,
#   'name': 'Strive Thru Sports - AIM High',
#   'category': 'Webseries',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2014-10-28',
#   'goal': 10000.0,
#   'launched': datetime.datetime(2014, 8, 30, 0, 35, 12),
#   'pledged': 100.0,
#   'state': 'failed',
#   'backers': 4,
#   'country': 'US',
#   'usd pledged': 100.0,
#   'usd_pledged_real': 100.0},
#  {'_id': 2033359917,
#   'name': 'Championship Trophy Sports Bottles, (CTS Bottles)',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2017-05-05',
#   'goal': 15000.0,
#   'launched': datetime.datetime(2017, 4, 7, 3, 20, 55),
#   'pledged': 650.0,
#   'state': 'failed',
#   'backers': 19,
#   'country': 'US',
#   'usd pledged': 177.0,
#   'usd_pledged_real': 650.0},
#  {'_id': 1380764438,
#   'name': 'Mi Sports Profile - Prepare to Succeed',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'AUD',
#   'deadline': '2014-10-10',
#   'goal': 35000.0,
#   'launched': datetime.datetime(2014, 9, 10, 15, 14, 52),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'AU',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 2070330391,
#   'name': 'Birth of a Sport: American Football in India and Pakistan',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2012-12-22',
#   'goal': 70000.0,
#   'launched': datetime.datetime(2012, 11, 21, 17, 55, 23),
#   'pledged': 12166.0,
#   'state': 'failed',
#   'backers': 145,
#   'country': 'US',
#   'usd pledged': 12166.0,
#   'usd_pledged_real': 12166.0},
#  {'_id': 1500242962,
#   'name': 'Zumer Sport:Lunch Boxes Made From Actual Sport Ball Material',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2014-12-13',
#   'goal': 15000.0,
#   'launched': datetime.datetime(2014, 11, 13, 22, 45, 35),
#   'pledged': 456.0,
#   'state': 'failed',
#   'backers': 13,
#   'country': 'US',
#   'usd pledged': 456.0,
#   'usd_pledged_real': 456.0},
#  {'_id': 1728490690,
#   'name': 'Carat Pro - Heart Rate Monitor & 4GB Storage Sport Earbuds',
#   'category': 'Sound',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-01-15',
#   'goal': 50000.0,
#   'launched': datetime.datetime(2016, 12, 6, 14, 5, 4),
#   'pledged': 51881.0,
#   'state': 'successful',
#   'backers': 271,
#   'country': 'US',
#   'usd pledged': 13850.0,
#   'usd_pledged_real': 51881.0},
#  {'_id': 1938753898,
#   'name': 'Basketball Coaching Tutorial (Sports)',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-08-06',
#   'goal': 1500.0,
#   'launched': datetime.datetime(2016, 7, 7, 19, 43, 50),
#   'pledged': 199.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 199.0,
#   'usd_pledged_real': 199.0},
#  {'_id': 833299467,
#   'name': 'The World of United Sport (Canceled)',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2016-01-28',
#   'goal': 2600.0,
#   'launched': datetime.datetime(2015, 12, 29, 21, 59, 22),
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1877625061,
#   'name': "That's My Team! :The History Behind Sports Teams' Names",
#   'category': 'Young Adult',
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2017-11-24',
#   'goal': 5000.0,
#   'launched': datetime.datetime(2017, 10, 30, 6, 14, 25),
#   'pledged': 5.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 5.0},
#  {'_id': 1875366029,
#   'name': 'Sport Smart. A New Genre of Sports TV. Sport Fans Unite!!!',
#   'category': 'Webseries',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2011-01-15',
#   'goal': 4500.0,
#   'launched': datetime.datetime(2010, 12, 16, 8, 40, 2),
#   'pledged': 25.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 25.0,
#   'usd_pledged_real': 25.0},
#  {'_id': 1133648228,
#   'name': 'DIY Wateproof Kit For Earbuds & mp3 players Made For Sports',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'GBP',
#   'deadline': '2014-11-12',
#   'goal': 4500.0,
#   'launched': datetime.datetime(2014, 10, 8, 20, 57, 13),
#   'pledged': 1.0,
#   'state': 'canceled',
#   'backers': 1,
#   'country': 'GB',
#   'usd pledged': 1.60412452,
#   'usd_pledged_real': 1.5654596972400947},
#  {'_id': 244965866,
#   'name': 'Ethical Polo: The Ultimate Sports Fit Polo Shirt',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'AUD',
#   'deadline': '2016-11-23',
#   'goal': 15000.0,
#   'launched': datetime.datetime(2016, 10, 9, 18, 1, 17),
#   'pledged': 463.0,
#   'state': 'failed',
#   'backers': 8,
#   'country': 'AU',
#   'usd pledged': 111.55166883,
#   'usd_pledged_real': 344.6222553033124},
#  {'_id': 427315121,
#   'name': 'Crayfish Sports Bar',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2015-09-24',
#   'goal': 795000.0,
#   'launched': datetime.datetime(2015, 8, 9, 1, 27, 26),
#   'pledged': 10.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 10.0,
#   'usd_pledged_real': 10.0},
#  {'_id': 96596569,
#   'name': 'A New Sport Show For The New Generation of Sports Fans!',
#   'category': 'Webseries',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2014-03-12',
#   'goal': 3000.0,
#   'launched': datetime.datetime(2014, 2, 13, 23, 18, 14),
#   'pledged': 30.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 30.0,
#   'usd_pledged_real': 30.0},
#  {'_id': 1661563672,
#   'name': 'Jalape?oï¿½ | Portable Beat Maker for Action Sports',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-02-07',
#   'goal': 53000.0,
#   'launched': datetime.datetime(2014, 1, 8, 14, 59, 52),
#   'pledged': 10424.0,
#   'state': 'failed',
#   'backers': 105,
#   'country': 'US',
#   'usd pledged': 10424.0,
#   'usd_pledged_real': 10424.0},
#  {'_id': 647933794,
#   'name': 'Jewish Sports Heritage Magazine',
#   'category': 'Literary Journals',
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2014-11-06',
#   'goal': 7500.0,
#   'launched': datetime.datetime(2014, 10, 7, 21, 23, 25),
#   'pledged': 10.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 10.0,
#   'usd_pledged_real': 10.0},
#  {'_id': 1577431293,
#   'name': 'Keep MSA Sports in Western PA!',
#   'category': 'Audio',
#   'main_category': 'Journalism',
#   'currency': 'USD',
#   'deadline': '2017-09-03',
#   'goal': 85000.0,
#   'launched': datetime.datetime(2017, 8, 4, 22, 0, 34),
#   'pledged': 21363.0,
#   'state': 'canceled',
#   'backers': 135,
#   'country': 'US',
#   'usd pledged': 430.0,
#   'usd_pledged_real': 21363.0},
#  {'_id': 1107829629,
#   'name': 'Finally a place to store Mouth Guards- The Sports Pocket',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-06-07',
#   'goal': 10000.0,
#   'launched': datetime.datetime(2016, 5, 13, 19, 35, 38),
#   'pledged': 567.0,
#   'state': 'failed',
#   'backers': 12,
#   'country': 'US',
#   'usd pledged': 567.0,
#   'usd_pledged_real': 567.0},
#  {'_id': 1298882779,
#   'name': "First Women's Sports Network: MyWSports",
#   'category': 'Journalism',
#   'main_category': 'Journalism',
#   'currency': 'USD',
#   'deadline': '2016-01-01',
#   'goal': 50000.0,
#   'launched': datetime.datetime(2015, 11, 17, 17, 59, 13),
#   'pledged': 50.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 50.0,
#   'usd_pledged_real': 50.0},
#  {'_id': 364260826,
#   'name': 'High-end Sports in-ear headphones by TRINITY AUDIO',
#   'category': 'Wearables',
#   'main_category': 'Technology',
#   'currency': 'GBP',
#   'deadline': '2015-09-10',
#   'goal': 60000.0,
#   'launched': datetime.datetime(2015, 8, 10, 14, 12, 5),
#   'pledged': 25243.0,
#   'state': 'canceled',
#   'backers': 218,
#   'country': 'GB',
#   'usd pledged': 39114.78452785,
#   'usd_pledged_real': 38932.416175699436},
#  {'_id': 434702919,
#   'name': "OrbXChairï¿½, The Perfect Sportsman's Chair for all Events",
#   'category': 'Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2013-03-31',
#   'goal': 108000.0,
#   'launched': datetime.datetime(2013, 3, 1, 4, 40, 23),
#   'pledged': 1273.0,
#   'state': 'failed',
#   'backers': 11,
#   'country': 'US',
#   'usd pledged': 1273.0,
#   'usd_pledged_real': 1273.0},
#  {'_id': 307748810,
#   'name': 'TRUEnergy - Green Tea Sports Shot',
#   'category': 'Drinks',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2015-12-17',
#   'goal': 20000.0,
#   'launched': datetime.datetime(2015, 11, 17, 15, 3, 2),
#   'pledged': 22723.0,
#   'state': 'successful',
#   'backers': 262,
#   'country': 'US',
#   'usd pledged': 22723.0,
#   'usd_pledged_real': 22723.0},
#  {'_id': 2094312119,
#   'name': 'Buena High Aquatic Sports Mural',
#   'category': 'Public Art',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2013-01-31',
#   'goal': 1500.0,
#   'launched': datetime.datetime(2013, 1, 9, 16, 24, 20),
#   'pledged': 1608.0,
#   'state': 'successful',
#   'backers': 40,
#   'country': 'US',
#   'usd pledged': 1608.0,
#   'usd_pledged_real': 1608.0},
#  {'_id': 1936044993,
#   'name': '"One Strings" Hi Tech Italian Sport Brand',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': '2017-05-16',
#   'goal': 20000.0,
#   'launched': datetime.datetime(2017, 4, 16, 19, 54, 58),
#   'pledged': 134.0,
#   'state': 'canceled',
#   'backers': 1,
#   'country': 'IT',
#   'usd pledged': 168.7466364,
#   'usd_pledged_real': 149.79933596413758},
#  {'_id': 1663335290,
#   'name': 'eSport Manager',
#   'category': 'Mobile Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2017-10-14',
#   'goal': 20000.0,
#   'launched': datetime.datetime(2017, 9, 14, 7, 31, 19),
#   'pledged': 15.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'DE',
#   'usd pledged': 5.991382,
#   'usd_pledged_real': 17.72693430398147},
#  {'_id': 1859849153,
#   'name': 'In Search of Sport: Ulama',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'AUD',
#   'deadline': '2015-02-22',
#   'goal': 30000.0,
#   'launched': datetime.datetime(2015, 1, 23, 7, 49, 29),
#   'pledged': 2.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'AU',
#   'usd pledged': 1.61296176,
#   'usd_pledged_real': 1.5656802880851728},
#  {'_id': 203600143,
#   'name': 'GYMNASTICS Poster - Sport in Art Poster Series #2',
#   'category': 'Graphic Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2014-10-21',
#   'goal': 600.0,
#   'launched': datetime.datetime(2014, 9, 21, 4, 59, 12),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 990697139,
#   'name': 'Plair Sports and Apparel Fall 2016 HBCU Line',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2016-06-14',
#   'goal': 5000.0,
#   'launched': datetime.datetime(2016, 4, 15, 14, 16, 7),
#   'pledged': 700.0,
#   'state': 'failed',
#   'backers': 8,
#   'country': 'US',
#   'usd pledged': 700.0,
#   'usd_pledged_real': 700.0},
#  {'_id': 1412647726,
#   'name': '1966 Fashion statement: Classic Sportcars Race Le Mans 1966',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'GBP',
#   'deadline': '2014-03-15',
#   'goal': 7800.0,
#   'launched': datetime.datetime(2014, 1, 29, 22, 44, 13),
#   'pledged': 21.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'GB',
#   'usd pledged': 34.87821687,
#   'usd_pledged_real': 34.62718068792665},
#  {'_id': 2008099012,
#   'name': "Sportzgirlz - Women's Sports Coverage",
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'AUD',
#   'deadline': '2015-02-26',
#   'goal': 4400.0,
#   'launched': datetime.datetime(2015, 1, 28, 22, 45, 39),
#   'pledged': 2.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'AU',
#   'usd pledged': 1.58563792,
#   'usd_pledged_real': 1.5656802880851728},
#  {'_id': 377805062,
#   'name': 'Intro To: Sports Tech and THE Sports Techie Online Community',
#   'category': 'Journalism',
#   'main_category': 'Journalism',
#   'currency': 'USD',
#   'deadline': '2016-10-01',
#   'goal': 8000.0,
#   'launched': datetime.datetime(2016, 9, 7, 1, 32, 35),
# ...
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 310904408,
#   'name': 'PROJECT X - Sports Based Reality TV Show (Canceled)',
#   'category': 'Television',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2014-08-02',
#   'goal': 18000.0,
#   'launched': datetime.datetime(2014, 7, 3, 3, 47, 17),
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1935410492,
#   'name': 'Bazadee Sports (Canceled)',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-05-06',
#   'goal': 2000000.0,
#   'launched': datetime.datetime(2015, 4, 6, 1, 48, 58),
#   'pledged': 10.0,
#   'state': 'canceled',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 10.0,
#   'usd_pledged_real': 10.0},
#  {'_id': 1304467963,
#   'name': 'Opinionated Sports Online Fantasy Games',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-06-30',
#   'goal': 5000.0,
#   'launched': datetime.datetime(2017, 5, 31, 3, 38, 31),
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 1.0},
#  {'_id': 841745614,
#   'name': "Moving Target: The Fate of Bhutan's National Sport",
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2016-05-21',
#   'goal': 18000.0,
#   'launched': datetime.datetime(2016, 4, 26, 20, 25, 44),
#   'pledged': 3430.0,
#   'state': 'failed',
#   'backers': 22,
#   'country': 'US',
#   'usd pledged': 3430.0,
#   'usd_pledged_real': 3430.0},
#  {'_id': 1283681878,
#   'name': 'Get Psyched For Spandex Shorts! Revolutionizing Sportswear.',
#   'category': 'Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2011-11-07',
#   'goal': 35000.0,
#   'launched': datetime.datetime(2011, 9, 23, 17, 16, 9),
#   'pledged': 2085.0,
#   'state': 'failed',
#   'backers': 24,
#   'country': 'US',
#   'usd pledged': 2085.0,
#   'usd_pledged_real': 2085.0},
#  {'_id': 423826472,
#   'name': 'TrigSport/ sport social network prototype',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'GBP',
#   'deadline': '2015-11-08',
#   'goal': 7000.0,
#   'launched': datetime.datetime(2015, 10, 9, 18, 6, 30),
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'GB',
#   'usd pledged': 1.53141467,
#   'usd_pledged_real': 1.5223712454519165},
#  {'_id': 648884755,
#   'name': 'SFBN: YOUR Home for High School Sports News and Information',
#   'category': 'Video',
#   'main_category': 'Journalism',
#   'currency': 'USD',
#   'deadline': '2017-08-11',
#   'goal': 8000.0,
#   'launched': datetime.datetime(2017, 6, 27, 21, 8, 2),
#   'pledged': 390.0,
#   'state': 'failed',
#   'backers': 6,
#   'country': 'US',
#   'usd pledged': 10.0,
#   'usd_pledged_real': 390.0},
#  {'_id': 1081541783,
#   'name': 'Daily Fantasy Sports | Sports Analytics Platform | DFS',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-12-09',
#   'goal': 33750.0,
#   'launched': datetime.datetime(2017, 11, 12, 14, 48, 42),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 908971555,
#   'name': 'Pretty Faces | All Female Ski & Adventure Sports Film',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2014-01-16',
#   'goal': 60000.0,
#   'launched': datetime.datetime(2013, 12, 13, 19, 15, 17),
#   'pledged': 113534.33,
#   'state': 'successful',
#   'backers': 1087,
#   'country': 'US',
#   'usd pledged': 113534.33,
#   'usd_pledged_real': 113534.33},
#  {'_id': 876821007,
#   'name': 'Papi Girl: Reinventing Sportswear For The Female Fan!',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2014-10-24',
#   'goal': 75000.0,
#   'launched': datetime.datetime(2014, 9, 24, 13, 56, 33),
#   'pledged': 3110.0,
#   'state': 'failed',
#   'backers': 31,
#   'country': 'US',
#   'usd pledged': 3110.0,
#   'usd_pledged_real': 3110.0},
#  {'_id': 144583144,
#   'name': 'TAKEOVERSports',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-02-16',
#   'goal': 20000.0,
#   'launched': datetime.datetime(2017, 1, 17, 23, 44, 40),
#   'pledged': 35.0,
#   'state': 'canceled',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 35.0,
#   'usd_pledged_real': 35.0},
#  {'_id': 266098008,
#   'name': 'Fitness, Agility Ladder, Sports, Health, Training, wellness',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2017-02-09',
#   'goal': 10000.0,
#   'launched': datetime.datetime(2017, 1, 10, 3, 24, 13),
#   'pledged': 135.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 105.0,
#   'usd_pledged_real': 135.0},
#  {'_id': 1832407103,
#   'name': 'Covering Catholic Sports from Youth to College and Beyond',
#   'category': 'Video',
#   'main_category': 'Journalism',
#   'currency': 'USD',
#   'deadline': '2016-04-29',
#   'goal': 30000.0,
#   'launched': datetime.datetime(2016, 3, 15, 16, 7, 31),
#   'pledged': 2.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 2.0,
#   'usd_pledged_real': 2.0},
#  {'_id': 2111331354,
#   'name': 'UK Mountain Sport Bible',
#   'category': 'Web',
#   'main_category': 'Journalism',
#   'currency': 'GBP',
#   'deadline': '2015-10-03',
#   'goal': 5000.0,
#   'launched': datetime.datetime(2015, 8, 14, 13, 53, 30),
#   'pledged': 20.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'GB',
#   'usd pledged': 31.2418478,
#   'usd_pledged_real': 30.67908146830084},
#  {'_id': 1078281579,
#   'name': 'Skyline Sports',
#   'category': 'Painting',
#   'main_category': 'Art',
#   'currency': 'CAD',
#   'deadline': '2016-12-08',
#   'goal': 2000.0,
#   'launched': datetime.datetime(2016, 11, 17, 14, 32, 43),
#   'pledged': 277.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'CA',
#   'usd pledged': 205.92774442,
#   'usd_pledged_real': 210.21476815663655},
#  {'_id': 411567167,
#   'name': 'Sports Art History',
#   'category': 'Painting',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2016-12-31',
#   'goal': 15265.0,
#   'launched': datetime.datetime(2016, 11, 23, 13, 45, 14),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 229171863,
#   'name': 'Fanlys - Group Messaging for Sports',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-07-28',
#   'goal': 5000.0,
#   'launched': datetime.datetime(2017, 6, 28, 21, 24, 58),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 236292600,
#   'name': 'Win The Day - The Sport & Exercise Performance Tool-Kit',
#   'category': 'Publishing',
#   'main_category': 'Publishing',
#   'currency': 'GBP',
#   'deadline': '2017-11-29',
#   'goal': 7000.0,
#   'launched': datetime.datetime(2017, 10, 30, 0, 28, 27),
#   'pledged': 8224.0,
#   'state': 'successful',
#   'backers': 20,
#   'country': 'GB',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 11092.527650391152},
#  {'_id': 1841585352,
#   'name': 'Airfromthere Memories  Sports,Travel,Landmark Enthusiasts.',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-03-05',
#   'goal': 70000.0,
#   'launched': datetime.datetime(2016, 1, 5, 17, 34, 6),
#   'pledged': 412.0,
#   'state': 'failed',
#   'backers': 7,
#   'country': 'US',
#   'usd pledged': 412.0,
#   'usd_pledged_real': 412.0},
#  {'_id': 1419386475,
#   'name': 'CALLIGURT Design - Gadget for Laptop, Sport &Travel Bag',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2017-12-03',
#   'goal': 2900.0,
#   'launched': datetime.datetime(2017, 11, 28, 18, 25, 15),
#   'pledged': 356.0,
#   'state': 'failed',
#   'backers': 13,
#   'country': 'DE',
#   'usd pledged': 222.97687203,
#   'usd_pledged_real': 418.01700248931473},
#  {'_id': 852739236,
#   'name': 'PUGnPLAY - Pick-Up Games / Recreational Sports Network',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-02-07',
#   'goal': 17500.0,
#   'launched': datetime.datetime(2015, 1, 3, 21, 31, 10),
#   'pledged': 16.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 16.0,
#   'usd_pledged_real': 16.0},
#  {'_id': 126588602,
#   'name': 'Behinderten gerechtes Sport/Kaj?tboot, Gr??e 10 - 12 m',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2016-05-25',
#   'goal': 3000000.0,
#   'launched': datetime.datetime(2016, 4, 25, 18, 6, 17),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'DE',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1262248098,
#   'name': 'ShockFlyingï¿½ eSports Start Up (Canceled)',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2016-02-25',
#   'goal': 155.0,
#   'launched': datetime.datetime(2016, 1, 11, 17, 36, 25),
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 148270105,
#   'name': 'Tawny Shark: Sport Watch Inspired By Pilot And Solar System',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'CAD',
#   'deadline': '2015-09-14',
#   'goal': 10000.0,
#   'launched': datetime.datetime(2015, 8, 31, 2, 57, 5),
#   'pledged': 24402.0,
#   'state': 'successful',
#   'backers': 272,
#   'country': 'CA',
#   'usd pledged': 18481.0852989,
#   'usd_pledged_real': 18731.864588930683},
#  {'_id': 854211167,
#   'name': 'The Amphibious - The way of a Paralympic Sportsman',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2016-07-17',
#   'goal': 7420.0,
#   'launched': datetime.datetime(2016, 6, 20, 17, 4, 18),
#   'pledged': 106.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 105.0,
#   'usd_pledged_real': 106.0},
#  {'_id': 1766749777,
#   'name': 'France Retro Sport Jersey',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': '2016-07-10',
#   'goal': 375.0,
#   'launched': datetime.datetime(2016, 5, 26, 11, 10, 59),
#   'pledged': 47.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'ES',
#   'usd pledged': 52.38683309,
#   'usd_pledged_real': 52.301837241133725},
#  {'_id': 1710166877,
#   'name': 'Sausage Sports Club',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2016-09-07',
#   'goal': 15000.0,
#   'launched': datetime.datetime(2016, 8, 8, 17, 36, 29),
#   'pledged': 15883.77,
#   'state': 'successful',
#   'backers': 387,
#   'country': 'US',
#   'usd pledged': 795.0,
#   'usd_pledged_real': 15883.77},
#  {'_id': 1003481744,
#   'name': 'CONDUIT Sports - Dynamic Bone Conducting Headphones',
#   'category': 'Wearables',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-05-15',
#   'goal': 50000.0,
#   'launched': datetime.datetime(2017, 4, 10, 21, 11, 10),
#   'pledged': 106213.0,
#   'state': 'successful',
#   'backers': 1052,
#   'country': 'US',
#   'usd pledged': 2478.0,
#   'usd_pledged_real': 106213.0},
#  {'_id': 658325991,
#   'name': 'Eliminate Tan Lines with The Vee Strapless Sports Bra',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2014-05-25',
#   'goal': 30000.0,
#   'launched': datetime.datetime(2014, 4, 15, 22, 44, 9),
#   'pledged': 1519.0,
#   'state': 'failed',
#   'backers': 22,
#   'country': 'US',
#   'usd pledged': 1519.0,
#   'usd_pledged_real': 1519.0},
#  {'_id': 1147840746,
#   'name': 'Varsity Sports Network Makeover',
#   'category': 'Publishing',
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2014-12-17',
#   'goal': 150000.0,
#   'launched': datetime.datetime(2014, 11, 17, 22, 59, 44),
#   'pledged': 100.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 100.0,
#   'usd_pledged_real': 100.0},
#  {'_id': 2134681345,
#   'name': 'GPS DATUM Sports HD 1080p 60fps camera, Wireless Network',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'GBP',
#   'deadline': '2013-05-08',
#   'goal': 20000.0,
#   'launched': datetime.datetime(2013, 4, 8, 19, 46, 17),
#   'pledged': 700.0,
#   'state': 'canceled',
#   'backers': 8,
#   'country': 'GB',
#   'usd pledged': 1071.047145,
#   'usd_pledged_real': 1076.8236778143557},
#  {'_id': 1547684157,
#   'name': 'S2SA - Sport to Strap Adapter for Samsung Gear S2 Sport (3G)',
#   'category': 'Wearables',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2016-02-21',
#   'goal': 2700.0,
#   'launched': datetime.datetime(2016, 1, 22, 23, 36, 37),
#   'pledged': 909.0,
#   'state': 'failed',
#   'backers': 12,
#   'country': 'AT',
#   'usd pledged': 989.12506851,
#   'usd_pledged_real': 1000.4402377283734},
#  {'_id': 645692773,
#   'name': 'Worlds Collide Sports & Comics Bar',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2016-04-22',
#   'goal': 100000.0,
#   'launched': datetime.datetime(2016, 2, 22, 20, 10, 35),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 284217830,
#   'name': 'A Fantastic New Concept for Wireless, Smart Sport Headphones',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-07-12',
#   'goal': 50000.0,
#   'launched': datetime.datetime(2014, 6, 2, 9, 58, 5),
#   'pledged': 45321.0,
#   'state': 'canceled',
#   'backers': 84,
#   'country': 'US',
#   'usd pledged': 45321.0,
#   'usd_pledged_real': 45321.0},
#  {'_id': 9576483,
#   'name': 'Custom Official Sports Logo Rings - NCAA, NHL, NBA & NASCAR',
#   'category': 'Jewelry',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2017-02-24',
#   'goal': 1000.0,
#   'launched': datetime.datetime(2017, 1, 25, 23, 17, 46),
#   'pledged': 101.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 101.0},
#  {'_id': 792545664,
#   'name': 'SportsCard by Medical Concepts, llc',
#   'category': 'Software',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-06-05',
#   'goal': 13500.0,
#   'launched': datetime.datetime(2016, 5, 6, 23, 3, 23),
#   'pledged': 300.0,
#   'state': 'failed',
#   'backers': 4,
#   'country': 'US',
#   'usd pledged': 300.0,
#   'usd_pledged_real': 300.0},
#  {'_id': 33929889,
#   'name': 'Sports podcast',
#   'category': 'Audio',
#   'main_category': 'Journalism',
#   'currency': 'CAD',
#   'deadline': '2017-08-05',
#   'goal': 250.0,
#   'launched': datetime.datetime(2017, 7, 6, 1, 11, 27),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'CA',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 367445085,
#   'name': "The world's best Sports, Travel and Outdoor Jacket",
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': '2018-01-24',
#   'goal': 30000.0,
#   'launched': datetime.datetime(2017, 12, 11, 16, 5, 56),
#   'pledged': 108207.0,
#   'state': 'live',
#   'backers': 295,
#   'country': 'AT',
#   'usd pledged': 51111.37253068,
#   'usd_pledged_real': 131330.33146019685},
#  {'_id': 1224314059,
#   'name': 'Fantasy Fan Sports',
#   'category': 'Web',
#   'main_category': 'Journalism',
#   'currency': 'USD',
#   'deadline': '2015-10-26',
#   'goal': 10000.0,
#   'launched': datetime.datetime(2015, 9, 26, 21, 21, 36),
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 1.0,
#   'usd_pledged_real': 1.0},
#  {'_id': 1966574528,
#   'name': 'The Sports Towel - Help take my product to market.',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2016-03-13',
#   'goal': 16625.0,
#   'launched': datetime.datetime(2016, 2, 12, 1, 16, 51),
#   'pledged': 261.0,
#   'state': 'failed',
#   'backers': 5,
#   'country': 'US',
#   'usd pledged': 261.0,
#   'usd_pledged_real': 261.0}]
